# %% [markdown]
# <a href="https://colab.research.google.com/github/2840bongkoch/dataviz2025/blob/main/Copy_of_Pandas_101_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas

# %%
pandas.DataFrame({'A':[1,2,3],'B':[2,3,4]})
# Out:
#    A  B
# 0  1  2
# 1  2  3
# 2  3  4

# %%
import pandas as pd

# %%
pd.DataFrame({'A':[1,2,3],'B':[2,3,4]})
# Out:
#    A  B
# 0  1  2
# 1  2  3
# 2  3  4

# %% [markdown]
# ## Load Pandas Data แบบที่ 1 (ใช้ครั้งเดียว หาย)

# %%
bfs_outcome_df = pd.read_csv('/content/drive/MyDrive/Python&DataViz2025/Data/2025-01/2025-01-bedfordshire-stop-and-search.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1720306661.py in <cell line: 0>()
# ----> 1 bfs_outcome_df = pd.read_csv('/content/drive/MyDrive/Python&DataViz2025/Data/2025-01/2025-01-bedfordshire-stop-and-search.csv')
#
# ...

# %%
bfs_outcome_df.head(10)
# Out:
#              Type                       Date  Part of a policing operation  \
# 0   Person search  2025-01-01T00:35:00+00:00                         False
# 1   Person search  2025-01-01T02:30:00+00:00                         False
# 2   Person search  2025-01-01T02:30:00+00:00                         False
# 3   Person search  2025-01-01T02:30:00+00:00                         False
# 4   Person search  2025-01-01T02:30:00+00:00                         False
# 5   Person search  2025-01-01T10:00:00+00:00                         False
# 6  Vehicle search  2025-01-01T10:00:00+00:00                         False
# 7   Person search  2025-01-01T12:12:00+00:00                         False
# 8   Person search  2025-01-01T14:35:00+00:00                          True
# 9   Person search  2025-01-01T15:10:00+00:00                          True
#
#    Policing operation   Latitude  Longitude  Gender Age range  \
# 0                 NaN  51.881481  -0.413110    Male     25-34
# ...

# %% [markdown]
# ## Load Pandas Data แบบที่ 2 (ดึงจาก Google Drive)

# %%
import os

# %%
from google.colab import drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path_to_stopandsearch = '/content/drive/MyDrive/Python&DataViz2025/Data/2025-01/2025-01-bedfordshire-stop-and-search.csv'

# %%
cityoflondon = '/content/drive/MyDrive/Python&DataViz2025/Data/2025-01-city-of-london-stop-and-search.csv'

# %%
cityoflondon_df = pd.read_csv(cityoflondon)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-829600703.py in <cell line: 0>()
# ----> 1 cityoflondon_df = pd.read_csv(cityoflondon)
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
# ...

# %%
stopandsearch_df = pd.read_csv(path_to_stopandsearch)
stopandsearch_df
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T00:35:00+00:00
# 1                Person search  2025-01-01T02:30:00+00:00
# 2                Person search  2025-01-01T02:30:00+00:00
# 3                Person search  2025-01-01T02:30:00+00:00
# 4                Person search  2025-01-01T02:30:00+00:00
# ..                         ...                        ...
# 382              Person search  2025-01-31T21:24:00+00:00
# 383              Person search  2025-01-31T21:35:00+00:00
# 384              Person search  2025-01-31T22:15:00+00:00
# 385              Person search  2025-01-31T23:23:00+00:00
# 386  Person and Vehicle search  2025-01-31T23:25:00+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                           False                 NaN  51.881481  -0.413110
# 1                           False                 NaN  52.132059  -0.296600
# ...

# %%
stopandsearch_df.head()
# Out:
#             Type                       Date  Part of a policing operation  \
# 0  Person search  2025-01-01T00:35:00+00:00                         False
# 1  Person search  2025-01-01T02:30:00+00:00                         False
# 2  Person search  2025-01-01T02:30:00+00:00                         False
# 3  Person search  2025-01-01T02:30:00+00:00                         False
# 4  Person search  2025-01-01T02:30:00+00:00                         False
#
#    Policing operation   Latitude  Longitude  Gender Age range  \
# 0                 NaN  51.881481   -0.41311    Male     25-34
# 1                 NaN  52.132059   -0.29660    Male     10-17
# 2                 NaN  52.132059   -0.29660    Male     10-17
# 3                 NaN  52.132059   -0.29660  Female     10-17
# 4                 NaN  52.132059   -0.29660    Male     10-17
#
#                               Self-defined ethnicity  \
# 0  Mixed/Multiple ethnic groups - Any other Mixed...
# ...

# %%
stopandsearch_df.tail()
# Out:
#                           Type                       Date  \
# 382              Person search  2025-01-31T21:24:00+00:00
# 383              Person search  2025-01-31T21:35:00+00:00
# 384              Person search  2025-01-31T22:15:00+00:00
# 385              Person search  2025-01-31T23:23:00+00:00
# 386  Person and Vehicle search  2025-01-31T23:25:00+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 382                         False                 NaN  52.134841  -0.483243
# 383                         False                 NaN  52.134841  -0.483243
# 384                         False                 NaN  51.881800  -0.368669
# 385                         False                 NaN  51.878459  -0.422384
# 386                         False                 NaN  51.878459  -0.422384
#
#      Gender Age range                             Self-defined ethnicity  \
# 382  Female   over 34  White - English/Welsh/Scottish/Northern Irish/...
# ...

# %%
stopandsearch_df.shape
# Out:
# (387, 15)

# %%
stopandsearch_df[11:384]
# Out:
#                           Type                       Date  \
# 11   Person and Vehicle search  2025-01-02T01:25:00+00:00
# 12               Person search  2025-01-02T09:20:00+00:00
# 13               Person search  2025-01-02T09:22:00+00:00
# 14               Person search  2025-01-02T10:00:00+00:00
# 15               Person search  2025-01-02T10:16:00+00:00
# ..                         ...                        ...
# 379              Person search  2025-01-31T19:04:00+00:00
# 380              Person search  2025-01-31T21:00:00+00:00
# 381              Person search  2025-01-31T21:24:00+00:00
# 382              Person search  2025-01-31T21:24:00+00:00
# 383              Person search  2025-01-31T21:35:00+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 11                          False                 NaN  51.878609  -0.415876
# 12                          False                 NaN        NaN        NaN
# ...

# %%
stopandsearch_df["Object of search"][384:386]
# Out:
# 384    Article for use in theft
# 385            Controlled drugs
# Name: Object of search, dtype: object

# %%
print(stopandsearch_df['Object of search'][5],stopandsearch_df['Object of search'][352])
# Out:
# Controlled drugs Controlled drugs

# %%
print(stopandsearch_df['Object of search'][5])
print(stopandsearch_df['Object of search'][382])
# Out:
# Controlled drugs
# Article for use in theft

# %% [markdown]
# ## ชี้ค่าในตาราง

# %% [markdown]
# #### basic

# %%
stopandsearch_df['Outcome']
# Out:
# 0                            Arrest
# 1      A no further action disposal
# 2      A no further action disposal
# 3      A no further action disposal
# 4      A no further action disposal
#                    ...
# 382    A no further action disposal
# 383    A no further action disposal
# 384            Community resolution
# 385    A no further action disposal
# 386    A no further action disposal
# Name: Outcome, Length: 387, dtype: object

# %%
stopandsearch_df['Outcome'][200]
# Out:
# 'A no further action disposal'

# %%
stopandsearch_df['Object of search'][100]
# Out:
# 'Offensive weapons'

# %% [markdown]
# ## list ซ้อน lust ซ้อน list ซ้อน dict ซ้อน list

# %%
ex_list = [[[1,2,3],['a','b','c']],
          [['x','y','z'],['ab',1,2]],
          [{'a':1,'b':2},{'xx':5,'yy':6}]]

# %%
ex_list[2][1]['xx']
# Out:
# 5

# %%
ex_list[1][1][2]
# Out:
# 2

# %%
stopandsearch_df
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T00:35:00+00:00
# 1                Person search  2025-01-01T02:30:00+00:00
# 2                Person search  2025-01-01T02:30:00+00:00
# 3                Person search  2025-01-01T02:30:00+00:00
# 4                Person search  2025-01-01T02:30:00+00:00
# ..                         ...                        ...
# 382              Person search  2025-01-31T21:24:00+00:00
# 383              Person search  2025-01-31T21:35:00+00:00
# 384              Person search  2025-01-31T22:15:00+00:00
# 385              Person search  2025-01-31T23:23:00+00:00
# 386  Person and Vehicle search  2025-01-31T23:25:00+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                           False                 NaN  51.881481  -0.413110
# 1                           False                 NaN  52.132059  -0.296600
# ...

# %% [markdown]
# #### .iloc

# %% [markdown]
# ชี้ไปที่แถวหลัก มองข้อมูลเป็น array

# %%
stopandsearch_df.iloc[200,-3]
# Out:
# 'A no further action disposal'

# %%
stopandsearch_df.iloc[200,12]
# Out:
# 'A no further action disposal'

# %% [markdown]
# ## Table slicing

# %% [markdown]
# #### ตัดมาเฉพาะ column ที่ต้องการ

# %%
stopandsearch_df.head(2)
# Out:
#             Type                       Date  Part of a policing operation  \
# 0  Person search  2025-01-01T00:35:00+00:00                         False
# 1  Person search  2025-01-01T02:30:00+00:00                         False
#
#    Policing operation   Latitude  Longitude Gender Age range  \
# 0                 NaN  51.881481   -0.41311   Male     25-34
# 1                 NaN  52.132059   -0.29660   Male     10-17
#
#                               Self-defined ethnicity  \
# 0  Mixed/Multiple ethnic groups - Any other Mixed...
# 1  White - English/Welsh/Scottish/Northern Irish/...
#
#   Officer-defined ethnicity  \
# 0                     Other
# 1                     White
#
#                                          Legislation   Object of search  \
# 0  Police and Criminal Evidence Act 1984 (section 1)  Offensive weapons
# 1  Police and Criminal Evidence Act 1984 (section 1)  Offensive weapons
#
#                         Outcome Outcome linked to object of search  \
# ...

# %%
smaller_table = stopandsearch_df[['Outcome','Age range','Longitude','Latitude','Self-defined ethnicity']][:5]
smaller_table
# Out:
#                         Outcome Age range  Longitude   Latitude  \
# 0                        Arrest     25-34   -0.41311  51.881481
# 1  A no further action disposal     10-17   -0.29660  52.132059
# 2  A no further action disposal     10-17   -0.29660  52.132059
# 3  A no further action disposal     10-17   -0.29660  52.132059
# 4  A no further action disposal     10-17   -0.29660  52.132059
#
#                               Self-defined ethnicity
# 0  Mixed/Multiple ethnic groups - Any other Mixed...
# 1  White - English/Welsh/Scottish/Northern Irish/...
# 2  White - English/Welsh/Scottish/Northern Irish/...
# 3  White - English/Welsh/Scottish/Northern Irish/...
# 4  White - English/Welsh/Scottish/Northern Irish/...

# %% [markdown]
# #### ตัดเฉพาะ rows และ columns ที่ต้องการ

# %% [markdown]
# ##### มองเป็น array ด้วย iloc แล้วตัดแบบ slice list

# %%
stopandsearch_df.iloc[1:5,:-10]
# Out:
#             Type                       Date  Part of a policing operation  \
# 1  Person search  2025-01-01T02:30:00+00:00                         False
# 2  Person search  2025-01-01T02:30:00+00:00                         False
# 3  Person search  2025-01-01T02:30:00+00:00                         False
# 4  Person search  2025-01-01T02:30:00+00:00                         False
#
#    Policing operation   Latitude
# 1                 NaN  52.132059
# 2                 NaN  52.132059
# 3                 NaN  52.132059
# 4                 NaN  52.132059

# %% [markdown]
# ## Table Query (row)
# แบบ advanced แต่ใช้ประโยชน์ได้เยอะกว่า (ตัดแบบใช้ logic query(conditional statement)

# %% [markdown]
# #### อยากได้ row ที่เป็น policing operation

# %%
stopandsearch_df.head(2)
# Out:
#             Type                       Date  Part of a policing operation  \
# 0  Person search  2025-01-01T00:35:00+00:00                         False
# 1  Person search  2025-01-01T02:30:00+00:00                         False
#
#    Policing operation   Latitude  Longitude Gender Age range  \
# 0                 NaN  51.881481   -0.41311   Male     25-34
# 1                 NaN  52.132059   -0.29660   Male     10-17
#
#                               Self-defined ethnicity  \
# 0  Mixed/Multiple ethnic groups - Any other Mixed...
# 1  White - English/Welsh/Scottish/Northern Irish/...
#
#   Officer-defined ethnicity  \
# 0                     Other
# 1                     White
#
#                                          Legislation   Object of search  \
# 0  Police and Criminal Evidence Act 1984 (section 1)  Offensive weapons
# 1  Police and Criminal Evidence Act 1984 (section 1)  Offensive weapons
#
#                         Outcome Outcome linked to object of search  \
# ...

# %%
stopandsearch_df['Part of a policing operation'] == True
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 382    False
# 383    False
# 384    False
# 385    False
# 386    False
# Name: Part of a policing operation, Length: 387, dtype: bool

# %%
stopandsearch_df['Part of a policing operation'] == False
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 382    True
# 383    True
# 384    True
# 385    True
# 386    True
# Name: Part of a policing operation, Length: 387, dtype: bool

# %%
stopandsearch_df[stopandsearch_df['Part of a policing operation'] == True ].head(2)
# Out:
#             Type                       Date  Part of a policing operation  \
# 8  Person search  2025-01-01T14:35:00+00:00                          True
# 9  Person search  2025-01-01T15:10:00+00:00                          True
#
#    Policing operation   Latitude  Longitude Gender Age range  \
# 8                 NaN  51.881571  -0.417059   Male  under 10
# 9                 NaN        NaN        NaN   Male   over 34
#
#                               Self-defined ethnicity  \
# 8  White - English/Welsh/Scottish/Northern Irish/...
# 9                 White - Any other White background
#
#   Officer-defined ethnicity                            Legislation  \
# 8                     White  Misuse of Drugs Act 1971 (section 23)
# 9                     White  Misuse of Drugs Act 1971 (section 23)
#
#    Object of search                       Outcome  \
# 8  Controlled drugs  A no further action disposal
# 9  Controlled drugs  A no further action disposal
#
# ...

# %% [markdown]
# ## ตัวอย่าง Table Query ง่ายๆ

# %%
smaller_table
# Out:
#                         Outcome Age range  Longitude   Latitude  \
# 0                        Arrest     25-34   -0.41311  51.881481
# 1  A no further action disposal     10-17   -0.29660  52.132059
# 2  A no further action disposal     10-17   -0.29660  52.132059
# 3  A no further action disposal     10-17   -0.29660  52.132059
# 4  A no further action disposal     10-17   -0.29660  52.132059
#
#                               Self-defined ethnicity
# 0  Mixed/Multiple ethnic groups - Any other Mixed...
# 1  White - English/Welsh/Scottish/Northern Irish/...
# 2  White - English/Welsh/Scottish/Northern Irish/...
# 3  White - English/Welsh/Scottish/Northern Irish/...
# 4  White - English/Welsh/Scottish/Northern Irish/...

# %%
smaller_table[[True, False, True, False, False]]
# Out:
#                         Outcome Age range  Longitude   Latitude  \
# 0                        Arrest     25-34   -0.41311  51.881481
# 2  A no further action disposal     10-17   -0.29660  52.132059
#
#                               Self-defined ethnicity
# 0  Mixed/Multiple ethnic groups - Any other Mixed...
# 2  White - English/Welsh/Scottish/Northern Irish/...

# %% [markdown]
# # quiz 6 query data ในตาราง มาเฉพาะ 10 ตัวแรก และ 15 ตัวสุดท้าย โดยใช้ list of logics ในการ query
#
# แสดงวิธีทำดังนี้
# 1. สร้าง list of logics
# 2. query

# %%
list_log1 = 10*[True] #สร้างลิสต์ที่มีค่าtrue 10 ค่า
list_log2 = 15*[True]

# %%
list_logM = (387-25)*[False] #ไม่เอาตรงกลาง

# %%
stopandsearch_df[list_log1+list_logM+list_log2] #โชวืตาราง
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T00:35:00+00:00
# 1                Person search  2025-01-01T02:30:00+00:00
# 2                Person search  2025-01-01T02:30:00+00:00
# 3                Person search  2025-01-01T02:30:00+00:00
# 4                Person search  2025-01-01T02:30:00+00:00
# 5                Person search  2025-01-01T10:00:00+00:00
# 6               Vehicle search  2025-01-01T10:00:00+00:00
# 7                Person search  2025-01-01T12:12:00+00:00
# 8                Person search  2025-01-01T14:35:00+00:00
# 9                Person search  2025-01-01T15:10:00+00:00
# 372              Person search  2025-01-31T13:13:00+00:00
# 373              Person search  2025-01-31T14:00:00+00:00
# 374              Person search  2025-01-31T14:54:00+00:00
# 375              Person search  2025-01-31T15:00:00+00:00
# 376              Person search  2025-01-31T16:20:00+00:00
# ...

# %%
first_10_rows = stopandsearch_df.head(10)
last_15_rows = stopandsearch_df.tail(15)
combined_rows = pd.concat([first_10_rows, last_15_rows])
display(combined_rows)
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T00:35:00+00:00
# 1                Person search  2025-01-01T02:30:00+00:00
# 2                Person search  2025-01-01T02:30:00+00:00
# 3                Person search  2025-01-01T02:30:00+00:00
# 4                Person search  2025-01-01T02:30:00+00:00
# 5                Person search  2025-01-01T10:00:00+00:00
# 6               Vehicle search  2025-01-01T10:00:00+00:00
# 7                Person search  2025-01-01T12:12:00+00:00
# 8                Person search  2025-01-01T14:35:00+00:00
# 9                Person search  2025-01-01T15:10:00+00:00
# 372              Person search  2025-01-31T13:13:00+00:00
# 373              Person search  2025-01-31T14:00:00+00:00
# 374              Person search  2025-01-31T14:54:00+00:00
# 375              Person search  2025-01-31T15:00:00+00:00
# 376              Person search  2025-01-31T16:20:00+00:00
# ...

# %% [markdown]
# ## การชี้ค่าในตารางด้วย df[***x***] ค่า ***x*** สามารถมีค่าที่ใส่เข้าไปได้ 2 แบบ
#
#
# 1.   ชื่อ column
# 2.   ใส่ rows ที่ต้องการ (ใส่ list ที่มี***ขนาดเท่ากับจำนวนแถว*** แล้วบอกว่าเอา แถวไหนบ้างโดยใช้ logical expression (```True```/```False```))

# %%
len('มุขตลก')
# Out:
# 6

# %%
folk_df['description'][0]
# Out:
# '<p>&nbsp; &nbsp; &nbsp; &nbsp; มีคนตาบอดหกคน ซึ่งเป็นเพื่อนรักกันอยู่ที่บ้านจันตคาม คนตาบอดทั้งหกได้เดินนออกมาคุยกันตามทางว่า</p>\n\n<p>&nbsp; &nbsp; &nbsp; &nbsp;&quot;เราจะพาไปตั้งวงดนตรีจะไปไหม?&quot; &quot;เราก็อยากร้องเพลงแบบนั้นแบบนี้นะ&quot;</p>\n\n<p>&nbsp; &nbsp; &nbsp; &nbsp; ตาบอดคนหนึ่งพูดขึ้นมาว่า&nbsp;&nbsp;&quot;นายจะร้องได้ไหม?&quot;</p>\n\n<p>&nbsp; &nbsp; &nbsp; &nbsp; อีกคนตอบ &quot;มันจะยากอะไร&quot;</p>\n\n<p>&nbsp; &nbsp; &nbsp; &nbsp; เมื่อคุยกันได้สักพัก ก็มีเจ้าเมืองซึ่งเป็นเจ้านายขี่ช้างมาตามทางแล้วก็ตะโกนขึ้นมาว่า</p>\n\n<p>&nbsp; &nbsp; &nbsp; &nbsp;&quot;หลบทางช้างเดินด้วย หลบท้างช้างเดินด้วย&quot;</p>\n\n<p>&nbsp; &nbsp; &nbsp; &nbsp; ตาบอดคนหนึ่งเลยพูดขึ้นมาว่า &quot;นั่นช้างหรอ&quot;</p>\n\n<p>&nbsp; &nbsp; &nbsp; &nbsp; ตาบอดเลยอยากรู้ว่าช้างเป็นอย่างไร จึงขอเจ้าเมืองจับช้าง&nbsp;เจ้าเมืองจึงอนุญาตและให้คนตาบอดเข้ามาจับช้างได้ทีละคน</p>\n\n<p>&nbsp; &nbsp; &nbsp; &nbsp; ตาบอดคนแรกเข้าเดินเข้าไปทางหางช้าง และเข้าไปจับที่หาง แล้วพูดขึ้นมาว่า</p>\n\n<p>
# ...

# %% [markdown]
# # Quiz 8-2
#
#
# 1.   อยากรู้ว่า ในเดือนกุมภาพันธ์ ปี 2025 ผู้ที่ถูกเรียกค้นที่เป็นคนขาว อังกฤษ เมือง city of london หรือ เมือง cambrigeshire มีเยอะกว่ากัน และเยอะกว่ากันเท่าไหร่

# %%
cityoflondon_count = cityoflondon_white_feb_df.shape[0]
cambridgeshire_count = cambridgeshire_white_feb_df.shape[0]

print(f"Number of incidents in City of London: {cityoflondon_count}")
print(f"Number of incidents in Cambridgeshire: {cambridgeshire_count}")

if cityoflondon_count > cambridgeshire_count:
    difference = cityoflondon_count - cambridgeshire_count
    print(f"City of London had more incidents by {difference}.")
elif cambridgeshire_count > cityoflondon_count:
    difference = cambridgeshire_count - cityoflondon_count
    print(f"Cambridgeshire had more incidents by {difference}.")
else:
    print("Both locations had the same number of incidents.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4106444454.py in <cell line: 0>()
# ----> 1 cityoflondon_count = cityoflondon_white_feb_df.shape[0]
#       2 cambridgeshire_count = cambridgeshire_white_feb_df.shape[0]
#       3
#       4 print(f"Number of incidents in City of London: {cityoflondon_count}")
#       5 print(f"Number of incidents in Cambridgeshire: {cambridgeshire_count}")
#
# NameError: name 'cityoflondon_white_feb_df' is not defined

# %%
cambridgeshire_feb_df = pd.read_csv('/content/drive/MyDrive/Python&DataViz2025/Data/2025-02/2025-02-cambridgeshire-stop-and-search.csv')

# %%
cambridgeshire_feb_df
# Out:
#                           Type                       Date  \
# 0                Person search  2025-02-01T03:40:00+00:00
# 1                Person search  2025-02-01T16:00:00+00:00
# 2    Person and Vehicle search  2025-02-02T03:53:00+00:00
# 3                Person search  2025-02-02T04:41:00+00:00
# 4                Person search  2025-02-02T04:46:00+00:00
# ..                         ...                        ...
# 164              Person search  2025-02-28T13:36:00+00:00
# 165              Person search  2025-02-28T13:36:00+00:00
# 166  Person and Vehicle search  2025-02-28T14:57:00+00:00
# 167              Person search  2025-02-28T18:07:00+00:00
# 168              Person search  2025-02-28T18:15:00+00:00
#
#     Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                           True                 NaN  52.329711  -0.083333
# 1                            NaN                 NaN  52.251723   0.107878
# ...

# %%
cityoflondon_feb_df= pd.read_csv('/content/drive/MyDrive/Python&DataViz2025/Data/2025-02/2025-02-city-of-london-stop-and-search.csv')

# %%
cityoflondon_feb_df
# Out:
#                           Type                       Date  \
# 0                Person search  2025-02-01T04:35:33+00:00
# 1                Person search  2025-02-01T14:24:45+00:00
# 2                Person search  2025-02-01T21:28:25+00:00
# 3                Person search  2025-02-01T21:35:37+00:00
# 4    Person and Vehicle search  2025-02-02T01:02:10+00:00
# ..                         ...                        ...
# 120              Person search  2025-02-28T18:45:46+00:00
# 121  Person and Vehicle search  2025-02-28T20:03:44+00:00
# 122              Person search  2025-02-28T21:25:07+00:00
# 123              Person search  2025-02-28T21:30:36+00:00
# 124              Person search  2025-02-28T22:12:07+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                             NaN                 NaN        NaN        NaN
# 1                             NaN                 NaN  51.514267  -0.079838
# ...

# %% [markdown]
# # HW 4 (group) ยอดรวมทั้ง 5 เดือน เมืองไหนมีจำนวนผู้ถูกเรียกค้นที่เป็นคน Asia น้อยที่สุด และ มากที่สุด

# %%
import pandas as pd
import os

# กำหนดเส้นทางหลักของโฟลเดอร์ข้อมูล
base_path = '/content/drive/MyDrive/Python&DataViz2025/Data/' # เปลี่ยนเส้นทางนี้หากข้อมูลไม่ได้อยู่ในโฟลเดอร์เดียวกัน

all_data = []

# วนลูปอ่านไฟล์ CSV ทั้งหมด
for folder_name in os.listdir(base_path):
    folder_path = os.path.join(base_path, folder_name)
    # ตรวจสอบว่าเป็นโฟลเดอร์หรือไม่
    if os.path.isdir(folder_path):
        for file_name in os.listdir(folder_path):
            # กรองเฉพาะไฟล์ 'stop-and-search' ที่เป็นนามสกุล .csv
            if 'stop-and-search' in file_name and file_name.endswith('.csv'):
                file_path = os.path.join(folder_path, file_name)
                try:
                    df = pd.read_csv(file_path)
                    # ดึงชื่อเมืองจากชื่อไฟล์
                    city = file_name.replace('-stop-and-search.csv', '').split('-', 2)[-1].strip()
                    df['City'] = city
                    all_data.append(df)
                except Exception as e:
                    print(f"ไม่สามารถอ่านไฟล์ได้: {file_path} : {e}")

# ถ้ามีข้อมูลที่อ่านได้
if all_data:
    # รวมข้อมูลทั้งหมดเข้าด้วยกัน
    combined_df = pd.concat(all_data, ignore_index=True)
    # กรองเฉพาะข้อมูลผู้ที่มีเชื้อสาย 'Asian' โดยไม่คำนึงถึงตัวพิมพ์เล็ก-ใหญ่
    asian_df = combined_df[combined_df['Self-defined ethnicity'].str.contains('Asian', case=False, na=False)]

    # นับจำนวนคนเอเชียในแต่ละเมือง
    asian_counts = asian_df['City'].value_counts()

    # แสดงผลลัพธ์ถ้ามีข้อมูล
    if not asian_counts.empty:
        most_city = asian_counts.idxmax()
        fewest_city = asian_counts.idxmin()

        print(f"เมืองที่มีจำนวนผู้ถูกเรียกค้นที่เป็นคน Asia น้อยที่สุด คือเมือง **{fewest_city}** จำนวน **{asian_counts[fewest_city]}** คน")
        print(f"เมืองที่มีจำนวนผู้ถูกเรียกค้นที่เป็นคน Asia มากที่สุด คือเมือง **{most_city}** จำนวน **{asian_counts[most_city]}** คน")
    else:
        print("ไม่พบข้อมูลที่เกี่ยวข้องกับผู้มีเชื้อสายเอเชีย")
else:
    print("ไม่พบไฟล์ข้อมูลในไดเรกทอรีที่ระบุ")
# Out:
# เมืองที่มีจำนวนผู้ถูกเรียกค้นที่เป็นคน Asia น้อยที่สุด คือเมือง **durham** จำนวน **5** คน
# เมืองที่มีจำนวนผู้ถูกเรียกค้นที่เป็นคน Asia มากที่สุด คือเมือง **west-midlands** จำนวน **2104** คน

# %%
#Real HW4
# นำเข้าโมดูล drive จาก google.colab เพื่อเข้าถึง Google Drive
from google.colab import drive
# นำเข้าไลบรารี pandas สำหรับจัดการและวิเคราะห์ข้อมูล
import pandas as pd
# นำเข้าโมดูล os สำหรับโต้ตอบกับระบบปฏิบัติการ เช่น การแสดงรายการไฟล์
import os
# นำเข้า defaultdict จาก collections เพื่อช่วยในการสร้าง dictionary ที่มีค่าเริ่มต้น
from collections import defaultdict

# เชื่อมต่อ Google Drive เข้ากับสภาพแวดล้อม Colab
drive.mount('/content/drive')

# กำหนดพาธหลักไปยังโฟลเดอร์ข้อมูลใน Google Drive
base_path = '/content/drive/MyDrive/Python&DataViz2025/Data/'

# สร้างลิสต์ว่างๆ เพื่อเก็บ DataFrame จากไฟล์ CSV ทั้งหมด
all_data = []

# วนลูปผ่านแต่ละโฟลเดอร์ (แทนแต่ละเดือน) ในพาธข้อมูลหลัก อ่านชื่อไฟล์ทุกตัวที่อยู่ในไฟล์ base_path
for month in os.listdir(base_path):
    # สร้างพาธแบบเต็มไปยังโฟลเดอร์ของเดือนปัจจุบัน
    #/content/drive/MyDrive/Python&DataViz2025/Data/2025-02
    month_path = os.path.join(base_path, month)
#-------------------------------------------------------------------------------
    # ตรวจสอบว่ารายการปัจจุบันเป็นไดเรกทอรี (โฟลเดอร์) หรือไม่
    if not os.path.isdir(month_path):
        # หากไม่ใช่ไดเรกทอรี ให้ข้ามไปยังรายการถัดไป
        continue
    # วนลูปผ่านแต่ละไฟล์ในโฟลเดอร์ของเดือนปัจจุบัน
    for file in os.listdir(month_path):
        # ตรวจสอบว่า 'stop-and-search' อยู่ในชื่อไฟล์หรือไม่
        if 'stop-and-search' not in file:
            # หากไฟล์ไม่ใช่ไฟล์ stop-and-search ให้ข้ามไปยังไฟล์ถัดไป
            continue
        # สร้างพาธแบบเต็มไปยังไฟล์ปัจจุบัน
        filepath = os.path.join(month_path, file)
#-------------------------------------------------------------------------------
        # ใช้บล็อก try-except เพื่อจัดการข้อผิดพลาดที่อาจเกิดขึ้นระหว่างการอ่านไฟล์
        try:
            # อ่านไฟล์ CSV เข้ามาเก็บไว้ใน pandas DataFrame
            df = pd.read_csv(filepath)
            # แยกชื่อเมืองออกจากชื่อไฟล์
            # โดยการแยกชื่อไฟล์ด้วย '-' และนำส่วนที่อยู่หลังปีและเดือน
            # จากนั้นรวมส่วนที่เหลือด้วย '-' และลบช่องว่างที่นำหน้า/ตามหลัง
            file_parts = file.replace('-stop-and-search.csv', '').split('-')
            #['2025', '01', 'bedfordshire']
            #['2025', '01', 'west', 'midlands']
            city = '-'.join(file_parts[2:]).strip()
            # เพิ่มคอลัมน์ใหม่ 'City' ไปยัง DataFrame และเติมชื่อเมืองที่แยกได้ลงไป
            df['City'] = city
            # เพิ่ม DataFrame ที่ประมวลผลแล้วเข้าในลิสต์ all_data
            all_data.append(df)
        # ดักจับข้อยกเว้นใดๆ ที่เกิดขึ้นระหว่างการประมวลผลไฟล์
        except Exception as e:
            # พิมพ์ข้อความแสดงข้อผิดพลาดหากไม่สามารถอ่านไฟล์ได้
            print(f"อ่านไฟล์ไม่ได้: {filepath} : {e}")
#-------------------------------------------------------------------------------
# ต่อ DataFrame ทั้งหมดในลิสต์ all_data เข้าด้วยกันเป็น DataFrame เดียว
# ignore_index=True จะรีเซ็ตดัชนีของ DataFrame ที่รวมเข้าด้วยกัน
combined_df = pd.concat(all_data, ignore_index=True)

# กรอง DataFrame ที่รวมเข้าด้วยกันเพื่อรวมเฉพาะแถวที่ 'Self-defined ethnicity' มีคำว่า 'Asian'
# na=False ทำให้แน่ใจว่าแถวที่มีค่าว่างใน 'Self-defined ethnicity' จะถูกยกเว้น
asian_df = combined_df[combined_df['Self-defined ethnicity'].str.contains('Asian', na=False)]

# นับจำนวนผู้ถูกเรียกค้นที่เป็นคนเอเชียแยกตามเมือง
#{'west-midlands': 2104, 'metropolitan': 2033, 'lancashire': 1301, ..., 'durham': 5}
asian_counts = asian_df['City'].value_counts().to_dict()

# หากมีข้อมูล ให้แสดงผลเมืองที่มีจำนวนน้อยที่สุดและมากที่สุด
if asian_counts:
    # หาเมืองที่มีจำนวนคนเอเชียมากที่สุด
    most_city = max(asian_counts, key=asian_counts.get)
    # หาเมืองที่มีจำนวนคนเอเชียน้อยที่สุด
    fewest_city = min(asian_counts, key=asian_counts.get)
    # พิมพ์เมืองที่มีจำนวนคนเอเชียน้อยที่สุดและจำนวนของพวกเขา
    print(f"เมืองที่มีจำนวนผู้ถูกเรียกค้นที่เป็นคน Asia น้อยที่สุด คือเมือง {fewest_city} จำนวน {asian_counts[fewest_city]} คน")
    # พิมพ์เมืองที่มีจำนวนคนเอเชียมากที่สุดและจำนวนของพวกเขา
    print(f"เมืองที่มีจำนวนผู้ถูกเรียกค้นที่เป็นคน Asia มากที่สุด คือเมือง {most_city} จำนวน {asian_counts[most_city]} คน")
# หาก dictionary asian_counts ว่างเปล่า (ไม่พบคนเอเชีย)
else:
    # พิมพ์ข้อความที่ระบุว่าไม่พบข้อมูลที่เกี่ยวข้อง
    print("ไม่พบข้อมูลที่เกี่ยวข้องกับผู้มีเชื้อสายเอเชีย")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# เมืองที่มีจำนวนผู้ถูกเรียกค้นที่เป็นคน Asia น้อยที่สุด คือเมือง durham จำนวน 5 คน
# เมืองที่มีจำนวนผู้ถูกเรียกค้นที่เป็นคน Asia มากที่สุด คือเมือง west-midlands จำนวน 2104 คน

# %% [markdown]
# #HW5 แก้จากโค้ดเดิม ยอดรวมทุกเมือง เดือนไหนมีจำนวนผู้ถูกเรียกค้นที่เป็นค้นเอเชียมากที่สุดและน้อยที่สุด

# %%
# นำเข้าโมดูลที่จำเป็น
from google.colab import drive
import pandas as pd
import os

# เชื่อมต่อ Google Drive เข้ากับสภาพแวดล้อม Colab
drive.mount('/content/drive')

# กำหนดพาธหลักไปยังโฟลเดอร์ข้อมูลใน Google Drive
base_path = '/content/drive/MyDrive/Python&DataViz2025/Data/'

all_data = []

# วนลูปผ่านแต่ละโฟลเดอร์ (แทนแต่ละเดือน) ในพาธข้อมูลหลัก
for month in os.listdir(base_path):
    month_path = os.path.join(base_path, month)

    if not os.path.isdir(month_path):
        continue

    for file in os.listdir(month_path):
        if 'stop-and-search' not in file:
            continue
        filepath = os.path.join(month_path, file)

        try:
            df = pd.read_csv(filepath)

            # เพิ่มคอลัมน์ 'Month' ที่มาจากชื่อโฟลเดอร์
            df['Month'] = month
            all_data.append(df)
        except Exception as e:
            print(f"อ่านไฟล์ไม่ได้: {filepath} : {e}")

# ต่อ DataFrame ทั้งหมดเข้าด้วยกัน
combined_df = pd.concat(all_data, ignore_index=True)

# กรองเฉพาะข้อมูลของคนเอเชีย
asian_df = combined_df[combined_df['Self-defined ethnicity'].str.contains('Asian', na=False)]

# นับจำนวนผู้ถูกเรียกค้นที่เป็นคนเอเชียแยกตามเดือน
asian_counts_by_month = asian_df['Month'].value_counts().to_dict()

# หากมีข้อมูล ให้แสดงผลเดือนที่มีจำนวนน้อยที่สุดและมากที่สุด
if asian_counts_by_month:
    # หาเดือนที่มีจำนวนคนเอเชียมากที่สุด
    most_month = max(asian_counts_by_month, key=asian_counts_by_month.get)
    # หาเดือนที่มีจำนวนคนเอเชียน้อยที่สุด
    fewest_month = min(asian_counts_by_month, key=asian_counts_by_month.get)

    print(f"เดือนที่มีจำนวนผู้ถูกเรียกค้นที่เป็นคน Asia มากที่สุด คือเดือน {most_month} จำนวน {asian_counts_by_month[most_month]} คน")
    print(f"เดือนที่มีจำนวนผู้ถูกเรียกค้นที่เป็นคน Asia น้อยที่สุด คือเดือน {fewest_month} จำนวน {asian_counts_by_month[fewest_month]} คน")
else:
    print("ไม่พบข้อมูลที่เกี่ยวข้องกับผู้มีเชื้อสายเอเชีย")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# เดือนที่มีจำนวนผู้ถูกเรียกค้นที่เป็นคน Asia มากที่สุด คือเดือน 2025-01 จำนวน 2874 คน
# เดือนที่มีจำนวนผู้ถูกเรียกค้นที่เป็นคน Asia น้อยที่สุด คือเดือน 2025-05 จำนวน 1737 คน

# %% [markdown]
# #การจัดการ Missing Value

# %% [markdown]
# การจัดการ Missing Value
#
# - ลบ record ที่เป็น missing
# - แทนที่ ค่า missing ด้วยค่าที่เหมาะสม mean, default, category-unknown #ใส่ดัมมี่
# - ใช้ ค่าจาก columns อื่นๆ ช่วยประมาณค่า ค่าใน column ที่หายไป (regression, deep learning, etc.)

# %% [markdown]
# # ตรวจดูว่าตารางมีมิสซิ่งรึป่าว

# %%
stopandsearch_df.isnull() #true คือ missing
# Out:
#       Type   Date  Part of a policing operation  Policing operation  Latitude  \
# 0    False  False                         False                True     False
# 1    False  False                         False                True     False
# 2    False  False                         False                True     False
# 3    False  False                         False                True     False
# 4    False  False                         False                True     False
# ..     ...    ...                           ...                 ...       ...
# 382  False  False                         False                True     False
# 383  False  False                         False                True     False
# 384  False  False                         False                True     False
# 385  False  False                         False                True     False
# 386  False  False                         False                True     False
#
# ...

# %%
stopandsearch_df.isnull().any() #เอาแต่ละแถวมา or กัน
# Out:
# Type                                        False
# Date                                        False
# Part of a policing operation                False
# Policing operation                           True
# Latitude                                     True
# Longitude                                    True
# Gender                                       True
# Age range                                    True
# Self-defined ethnicity                       True
# Officer-defined ethnicity                    True
# Legislation                                 False
# Object of search                            False
# Outcome                                     False
# Outcome linked to object of search           True
# Removal of more than just outer clothing    False
# dtype: bool

# %% [markdown]
# ### ลบ record (dropna)
#
# missing = ```None``` ```NA```(not autorized) ```NaN``` (not a number)  null

# %%
stopandsearch_df.dropna().shape
# Out:
# (0, 15)

# %%
stopandsearch_df.dropna()
# Out:
# Empty DataFrame
# Columns: [Type, Date, Part of a policing operation, Policing operation, Latitude, Longitude, Gender, Age range, Self-defined ethnicity, Officer-defined ethnicity, Legislation, Object of search, Outcome, Outcome linked to object of search, Removal of more than just outer clothing]
# Index: []

# %% [markdown]
# ## drop แบบเลือกเฉพาะบางคอมลัมม์

# %%
stopandsearch_df.dropna(subset=['Self-defined ethnicity','Legislation'])
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T00:35:00+00:00
# 1                Person search  2025-01-01T02:30:00+00:00
# 2                Person search  2025-01-01T02:30:00+00:00
# 3                Person search  2025-01-01T02:30:00+00:00
# 4                Person search  2025-01-01T02:30:00+00:00
# ..                         ...                        ...
# 382              Person search  2025-01-31T21:24:00+00:00
# 383              Person search  2025-01-31T21:35:00+00:00
# 384              Person search  2025-01-31T22:15:00+00:00
# 385              Person search  2025-01-31T23:23:00+00:00
# 386  Person and Vehicle search  2025-01-31T23:25:00+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                           False                 NaN  51.881481  -0.413110
# 1                           False                 NaN  52.132059  -0.296600
# ...

# %%
stopandsearch_df.head()
# Out:
#             Type                       Date  Part of a policing operation  \
# 0  Person search  2025-01-01T00:35:00+00:00                         False
# 1  Person search  2025-01-01T02:30:00+00:00                         False
# 2  Person search  2025-01-01T02:30:00+00:00                         False
# 3  Person search  2025-01-01T02:30:00+00:00                         False
# 4  Person search  2025-01-01T02:30:00+00:00                         False
#
#    Policing operation   Latitude  Longitude  Gender Age range  \
# 0                 NaN  51.881481   -0.41311    Male     25-34
# 1                 NaN  52.132059   -0.29660    Male     10-17
# 2                 NaN  52.132059   -0.29660    Male     10-17
# 3                 NaN  52.132059   -0.29660  Female     10-17
# 4                 NaN  52.132059   -0.29660    Male     10-17
#
#                               Self-defined ethnicity  \
# 0  Mixed/Multiple ethnic groups - Any other Mixed...
# ...

# %%
stopandsearch_df
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T00:35:00+00:00
# 1                Person search  2025-01-01T02:30:00+00:00
# 2                Person search  2025-01-01T02:30:00+00:00
# 3                Person search  2025-01-01T02:30:00+00:00
# 4                Person search  2025-01-01T02:30:00+00:00
# ..                         ...                        ...
# 382              Person search  2025-01-31T21:24:00+00:00
# 383              Person search  2025-01-31T21:35:00+00:00
# 384              Person search  2025-01-31T22:15:00+00:00
# 385              Person search  2025-01-31T23:23:00+00:00
# 386  Person and Vehicle search  2025-01-31T23:25:00+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                           False                 NaN  51.881481  -0.413110
# 1                           False                 NaN  52.132059  -0.296600
# ...

# %% [markdown]
# ## เลือกเฉพาะคอลัมม์ที่สนใจก่อนค่อย drop

# %%
stopandsearch_df[['Outcome','Type','Age range']].dropna()
# Out:
#                           Outcome                       Type Age range
# 0                          Arrest              Person search     25-34
# 1    A no further action disposal              Person search     10-17
# 2    A no further action disposal              Person search     10-17
# 3    A no further action disposal              Person search     10-17
# 4    A no further action disposal              Person search     10-17
# ..                            ...                        ...       ...
# 382  A no further action disposal              Person search   over 34
# 383  A no further action disposal              Person search     25-34
# 384          Community resolution              Person search   over 34
# 385  A no further action disposal              Person search     18-24
# 386  A no further action disposal  Person and Vehicle search     18-24
#
# [340 rows x 3 columns]

# %%
stopandsearch_df.dropna(subset=['Self-defined ethnicity','Legislation'],inplace=True)

# %%
stopandsearch_df.shape
# Out:
# (356, 15)

# %% [markdown]
# ## ลบเฉพาะ ค่าว่างใน column ที่เราต้องใช้

# %%
this_data = folk_df.dropna(subset='title')

# %%
this_data.shape
# Out:
# (226, 11)

# %%
this_data.shape
# Out:
# (218, 11)

# %% [markdown]
# ### แทน missing ด้วยค่าที่เหมาะสม (```fillna```)

# %% [markdown]
# # เติม dummy

# %%
stopandsearch_df.fillna('Unknown')
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T00:35:00+00:00
# 1                Person search  2025-01-01T02:30:00+00:00
# 2                Person search  2025-01-01T02:30:00+00:00
# 3                Person search  2025-01-01T02:30:00+00:00
# 4                Person search  2025-01-01T02:30:00+00:00
# ..                         ...                        ...
# 382              Person search  2025-01-31T21:24:00+00:00
# 383              Person search  2025-01-31T21:35:00+00:00
# 384              Person search  2025-01-31T22:15:00+00:00
# 385              Person search  2025-01-31T23:23:00+00:00
# 386  Person and Vehicle search  2025-01-31T23:25:00+00:00
#
#      Part of a policing operation Policing operation   Latitude Longitude  \
# 0                           False            Unknown  51.881481  -0.41311
# 1                           False            Unknown  52.132059   -0.2966
# ...

# %%
stopandsearch_df.fillna('Unknown').isnull().any()
# Out:
# Type                                        False
# Date                                        False
# Part of a policing operation                False
# Policing operation                          False
# Latitude                                    False
# Longitude                                   False
# Gender                                      False
# Age range                                   False
# Self-defined ethnicity                      False
# Officer-defined ethnicity                   False
# Legislation                                 False
# Object of search                            False
# Outcome                                     False
# Outcome linked to object of search          False
# Removal of more than just outer clothing    False
# dtype: bool

# %%
stopandsearch_df.fillna({'Gender':'Unknown'})
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T00:35:00+00:00
# 1                Person search  2025-01-01T02:30:00+00:00
# 2                Person search  2025-01-01T02:30:00+00:00
# 3                Person search  2025-01-01T02:30:00+00:00
# 4                Person search  2025-01-01T02:30:00+00:00
# ..                         ...                        ...
# 382              Person search  2025-01-31T21:24:00+00:00
# 383              Person search  2025-01-31T21:35:00+00:00
# 384              Person search  2025-01-31T22:15:00+00:00
# 385              Person search  2025-01-31T23:23:00+00:00
# 386  Person and Vehicle search  2025-01-31T23:25:00+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                           False                 NaN  51.881481  -0.413110
# 1                           False                 NaN  52.132059  -0.296600
# ...

# %%
stopandsearch_df.fillna({'Gender':'Unknown'}).isnull().any()
# Out:
# Type                                        False
# Date                                        False
# Part of a policing operation                False
# Policing operation                           True
# Latitude                                     True
# Longitude                                    True
# Gender                                      False
# Age range                                    True
# Self-defined ethnicity                      False
# Officer-defined ethnicity                    True
# Legislation                                 False
# Object of search                            False
# Outcome                                     False
# Outcome linked to object of search           True
# Removal of more than just outer clothing    False
# dtype: bool

# %%
stopandsearch_df.fillna({'Gender':'Unknown'}, inplace=False) #อัพเดทตาราง
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T00:35:00+00:00
# 1                Person search  2025-01-01T02:30:00+00:00
# 2                Person search  2025-01-01T02:30:00+00:00
# 3                Person search  2025-01-01T02:30:00+00:00
# 4                Person search  2025-01-01T02:30:00+00:00
# ..                         ...                        ...
# 382              Person search  2025-01-31T21:24:00+00:00
# 383              Person search  2025-01-31T21:35:00+00:00
# 384              Person search  2025-01-31T22:15:00+00:00
# 385              Person search  2025-01-31T23:23:00+00:00
# 386  Person and Vehicle search  2025-01-31T23:25:00+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                           False                 NaN  51.881481  -0.413110
# 1                           False                 NaN  52.132059  -0.296600
# ...

# %%
stopandsearch_df
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T00:35:00+00:00
# 1                Person search  2025-01-01T02:30:00+00:00
# 2                Person search  2025-01-01T02:30:00+00:00
# 3                Person search  2025-01-01T02:30:00+00:00
# 4                Person search  2025-01-01T02:30:00+00:00
# ..                         ...                        ...
# 382              Person search  2025-01-31T21:24:00+00:00
# 383              Person search  2025-01-31T21:35:00+00:00
# 384              Person search  2025-01-31T22:15:00+00:00
# 385              Person search  2025-01-31T23:23:00+00:00
# 386  Person and Vehicle search  2025-01-31T23:25:00+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                           False                 NaN  51.881481  -0.413110
# 1                           False                 NaN  52.132059  -0.296600
# ...

# %%
stopandsearch_df
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T00:35:00+00:00
# 1                Person search  2025-01-01T02:30:00+00:00
# 2                Person search  2025-01-01T02:30:00+00:00
# 3                Person search  2025-01-01T02:30:00+00:00
# 4                Person search  2025-01-01T02:30:00+00:00
# ..                         ...                        ...
# 382              Person search  2025-01-31T21:24:00+00:00
# 383              Person search  2025-01-31T21:35:00+00:00
# 384              Person search  2025-01-31T22:15:00+00:00
# 385              Person search  2025-01-31T23:23:00+00:00
# 386  Person and Vehicle search  2025-01-31T23:25:00+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                           False                 NaN  51.881481  -0.413110
# 1                           False                 NaN  52.132059  -0.296600
# ...

# %%
stopandsearch_df['Officer-defined ethnicity'].mode()
# Out:
# 0    White
# Name: Officer-defined ethnicity, dtype: object

# %% [markdown]
# ## ตรวจสอบค่าว่าง

# %%
folk_df['type'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 221    False
# 222    False
# 223    False
# 224    False
# 225    False
# Name: type, Length: 226, dtype: bool

# %%
folk_df['type'].isnull().any()    # เอาค่าทุกค่าใน list มา OR กัน (เราใช้อันนี้เพราะ ถ้ามี True แค่ 1 ค่ามันจะเป็น True)
# Out:
# False

# %%
folk_df['type'].isnull().all()    # เอาค่าทุกค่าใน list มา AND กัน
# Out:
# False

# %%
folk_df['spatial'].isnull().any()
# Out:
# True

# %% [markdown]
# # Quiz 7 นิทานเรื่องไหนที่ ค่า spatial เป็น ค่าว่าง (ไม่ใช้ gemini)

# %%
folk_df[folk_df['spatial'].isnull()]['title']
# Out:
# 34                 พญาคันคาก
# 75                 พญาคันคาก
# 76                   ผีตาแฮก
# 88           ทุ่งกุลาฮ่องไห้
# 96                 นางหมาขาว
# 112               ธุระไม่ใช่
# 113         ทำไมเสือจึงมีลาย
# 121            สามสหายสามโรค
# 148               ลิงกับเต่า
# 149                    ปูทอง
# 150           ศุภมิตร-เกศินี
# 173           คงรอดกับยอดทอง
# 183                 นกบินหลา
# 184    คนเลี้ยงเป็ดเจ้าปัญญา
# 185           งูเหลือมวิดปลา
# 192            กรรมเก่าของกา
# 193                กระดูกไก่
# 197         การละอายความชั่ว
# 202                   คนทีดำ
# 206                 คนพาซื่อ
# 209            ค่อยโถเอาใหม่
# 213                  จอมคาถา
# 214              จังไรฉิบหาย
# 215             ไชชายนายปลอก
# 220                  ตาแขนปม
# 223       เต่ากับพระพุทธเจ้า
# Name: title, dtype: object

# %% [markdown]
# ## ลบค่าซ้ำ (de-duplicate)

# %%
stopandsearch_df.shape
# Out:
# (356, 15)

# %% [markdown]
# ### เรียกดูแถวที่ซ่ำ

# %%
stopandsearch_df[stopandsearch_df.duplicated()] #ซ้ำขึ้น true
# Out:
#               Type                       Date  Part of a policing operation  \
# 2    Person search  2025-01-01T02:30:00+00:00                         False
# 4    Person search  2025-01-01T02:30:00+00:00                         False
# 43   Person search  2025-01-05T03:25:00+00:00                         False
# 86   Person search  2025-01-08T02:06:00+00:00                         False
# 87   Person search  2025-01-08T02:06:00+00:00                         False
# 88   Person search  2025-01-08T02:06:00+00:00                         False
# 231  Person search  2025-01-19T18:45:00+00:00                         False
# 243  Person search  2025-01-20T15:55:00+00:00                         False
# 244  Person search  2025-01-20T15:55:00+00:00                         False
# 245  Person search  2025-01-20T15:55:00+00:00                         False
# 308  Person search  2025-01-27T12:15:00+00:00                          True
#
# ...

# %%
stopandsearch_df[stopandsearch_df.duplicated()].dropna()
# Out:
# Empty DataFrame
# Columns: [Type, Date, Part of a policing operation, Policing operation, Latitude, Longitude, Gender, Age range, Self-defined ethnicity, Officer-defined ethnicity, Legislation, Object of search, Outcome, Outcome linked to object of search, Removal of more than just outer clothing]
# Index: []

# %%
stopandsearch_df
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T00:35:00+00:00
# 1                Person search  2025-01-01T02:30:00+00:00
# 2                Person search  2025-01-01T02:30:00+00:00
# 3                Person search  2025-01-01T02:30:00+00:00
# 4                Person search  2025-01-01T02:30:00+00:00
# ..                         ...                        ...
# 382              Person search  2025-01-31T21:24:00+00:00
# 383              Person search  2025-01-31T21:35:00+00:00
# 384              Person search  2025-01-31T22:15:00+00:00
# 385              Person search  2025-01-31T23:23:00+00:00
# 386  Person and Vehicle search  2025-01-31T23:25:00+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                           False                 NaN  51.881481  -0.413110
# 1                           False                 NaN  52.132059  -0.296600
# ...

# %%
stopandsearch_df.duplicated()
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 382    False
# 383    False
# 384    False
# 385    False
# 386    False
# Length: 356, dtype: bool

# %%
~stopandsearch_df.duplicated()
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 382     True
# 383     True
# 384     True
# 385     True
# 386     True
# Length: 356, dtype: bool

# %%
stopandsearch_df[~stopandsearch_df.duplicated()]
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T00:35:00+00:00
# 1                Person search  2025-01-01T02:30:00+00:00
# 3                Person search  2025-01-01T02:30:00+00:00
# 5                Person search  2025-01-01T10:00:00+00:00
# 7                Person search  2025-01-01T12:12:00+00:00
# ..                         ...                        ...
# 382              Person search  2025-01-31T21:24:00+00:00
# 383              Person search  2025-01-31T21:35:00+00:00
# 384              Person search  2025-01-31T22:15:00+00:00
# 385              Person search  2025-01-31T23:23:00+00:00
# 386  Person and Vehicle search  2025-01-31T23:25:00+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                           False                 NaN  51.881481  -0.413110
# 1                           False                 NaN  52.132059  -0.296600
# ...

# %%
stopandsearch_df[stopandsearch_df.duplicated()] == False
# Out:
#       Type   Date  Part of a policing operation  Policing operation  Latitude  \
# 2    False  False                          True               False     False
# 4    False  False                          True               False     False
# 43   False  False                          True               False     False
# 86   False  False                          True               False     False
# 87   False  False                          True               False     False
# 88   False  False                          True               False     False
# 231  False  False                          True               False     False
# 243  False  False                          True               False     False
# 244  False  False                          True               False     False
# 245  False  False                          True               False     False
# 308  False  False                         False               False     False
#
# ...

# %%
stopandsearch_df[stopandsearch_df.duplicated() == False]
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T00:35:00+00:00
# 1                Person search  2025-01-01T02:30:00+00:00
# 3                Person search  2025-01-01T02:30:00+00:00
# 5                Person search  2025-01-01T10:00:00+00:00
# 7                Person search  2025-01-01T12:12:00+00:00
# ..                         ...                        ...
# 382              Person search  2025-01-31T21:24:00+00:00
# 383              Person search  2025-01-31T21:35:00+00:00
# 384              Person search  2025-01-31T22:15:00+00:00
# 385              Person search  2025-01-31T23:23:00+00:00
# 386  Person and Vehicle search  2025-01-31T23:25:00+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                           False                 NaN  51.881481  -0.413110
# 1                           False                 NaN  52.132059  -0.296600
# ...

# %%
stopandsearch_df['title'].duplicated().any()
# Out:
# True

# %%
stopandsearch_df
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T00:35:00+00:00
# 1                Person search  2025-01-01T02:30:00+00:00
# 2                Person search  2025-01-01T02:30:00+00:00
# 3                Person search  2025-01-01T02:30:00+00:00
# 4                Person search  2025-01-01T02:30:00+00:00
# ..                         ...                        ...
# 382              Person search  2025-01-31T21:24:00+00:00
# 383              Person search  2025-01-31T21:35:00+00:00
# 384              Person search  2025-01-31T22:15:00+00:00
# 385              Person search  2025-01-31T23:23:00+00:00
# 386  Person and Vehicle search  2025-01-31T23:25:00+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                           False                 NaN  51.881481  -0.413110
# 1                           False                 NaN  52.132059  -0.296600
# ...

# %% [markdown]
# ### แทนค่าว่างด้วยค่ากลาง

# %%
stopandsearch_df
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T00:35:00+00:00
# 1                Person search  2025-01-01T02:30:00+00:00
# 2                Person search  2025-01-01T02:30:00+00:00
# 3                Person search  2025-01-01T02:30:00+00:00
# 4                Person search  2025-01-01T02:30:00+00:00
# ..                         ...                        ...
# 382              Person search  2025-01-31T21:24:00+00:00
# 383              Person search  2025-01-31T21:35:00+00:00
# 384              Person search  2025-01-31T22:15:00+00:00
# 385              Person search  2025-01-31T23:23:00+00:00
# 386  Person and Vehicle search  2025-01-31T23:25:00+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                           False                 NaN  51.881481  -0.413110
# 1                           False                 NaN  52.132059  -0.296600
# ...

# %%
stopandsearch_df.fillna({'Latitude':stopandsearch_df['Latitude'].mean()})
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T00:35:00+00:00
# 1                Person search  2025-01-01T02:30:00+00:00
# 2                Person search  2025-01-01T02:30:00+00:00
# 3                Person search  2025-01-01T02:30:00+00:00
# 4                Person search  2025-01-01T02:30:00+00:00
# ..                         ...                        ...
# 382              Person search  2025-01-31T21:24:00+00:00
# 383              Person search  2025-01-31T21:35:00+00:00
# 384              Person search  2025-01-31T22:15:00+00:00
# 385              Person search  2025-01-31T23:23:00+00:00
# 386  Person and Vehicle search  2025-01-31T23:25:00+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                           False                 NaN  51.881481  -0.413110
# 1                           False                 NaN  52.132059  -0.296600
# ...

# %%
stopandsearch_df.fillna({'Longitude':stopandsearch_df['Longitude'].mean()})
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T00:35:00+00:00
# 1                Person search  2025-01-01T02:30:00+00:00
# 2                Person search  2025-01-01T02:30:00+00:00
# 3                Person search  2025-01-01T02:30:00+00:00
# 4                Person search  2025-01-01T02:30:00+00:00
# ..                         ...                        ...
# 382              Person search  2025-01-31T21:24:00+00:00
# 383              Person search  2025-01-31T21:35:00+00:00
# 384              Person search  2025-01-31T22:15:00+00:00
# 385              Person search  2025-01-31T23:23:00+00:00
# 386  Person and Vehicle search  2025-01-31T23:25:00+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                           False                 NaN  51.881481  -0.413110
# 1                           False                 NaN  52.132059  -0.296600
# ...

# %%
stopandsearch_df.fillna({'Latitude':stopandsearch_df['Latitude'].mean(), #แทนค่า Lat ด้วย Mean
                         'Longitude':stopandsearch_df['Longitude'].mean(), #แทนค่า long ด้วย Mean
                         'Age range':stopandsearch_df['Age range'].mode()},
                        inplace = True) #แทนค่า Age ranf ด้วย mode

# %%
stopandsearch_df.isnull().any()
# Out:
# Type                                        False
# Date                                        False
# Part of a policing operation                False
# Policing operation                           True
# Latitude                                    False
# Longitude                                   False
# Gender                                      False
# Age range                                    True
# Self-defined ethnicity                      False
# Officer-defined ethnicity                    True
# Legislation                                 False
# Object of search                            False
# Outcome                                     False
# Outcome linked to object of search           True
# Removal of more than just outer clothing    False
# dtype: bool

# %% [markdown]
# # Quiz 9 หาดูว่า row ในบ้างที่ยังมี missing อยู่ใน คอลัมม์ Age rang อยู่

# %%
missing_age_rows = stopandsearch_df[stopandsearch_df['Age range'].isnull()]
display(missing_age_rows)
# Out:
#               Type                       Date  Part of a policing operation  \
# 52   Person search  2025-01-06T08:00:00+00:00                         False
# 77   Person search  2025-01-07T15:10:00+00:00                          True
# 83   Person search  2025-01-07T22:31:00+00:00                         False
# 228  Person search  2025-01-19T18:45:00+00:00                         False
# 231  Person search  2025-01-19T18:45:00+00:00                         False
# 242  Person search  2025-01-20T15:55:00+00:00                         False
# 243  Person search  2025-01-20T15:55:00+00:00                         False
# 244  Person search  2025-01-20T15:55:00+00:00                         False
# 245  Person search  2025-01-20T15:55:00+00:00                         False
# 282  Person search  2025-01-25T15:40:00+00:00                         False
# 296  Person search  2025-01-26T18:40:00+00:00                         False
# ...

# %%
folk_df[folk_df['title'].duplicated(keep=False)]
# Out:
#                   title            type             creator  \
# 2    ก่องข้าวน้อยฆ่าแม่      นิทานชีวิต  หนูเวียง แก้วเวียง
# 32   ก่องข้าวน้อยฆ่าแม่  นิทานประจำถิ่น  หนูเวียง แก้วเวียง
# 34            พญาคันคาก    ตำนานปรัมปรา   ภัสดาภร อินทะบุตร
# 38         กำพร้าผีน้อย      นิทานชีวิต                 NaN
# 43   ก่องข้าวน้อยฆ่าแม่  นิทานประจำถิ่น                 NaN
# 49             ผีกองกอย         นิทานผี                 NaN
# 75            พญาคันคาก    ตำนานปรัมปรา                 NaN
# 95         กำพร้าผีน้อย         นิทานผี                 NaN
# 100            ผีกองกอย         นิทานผี                 NaN
# 142            ผีกองกอย         นิทานผี                 NaN
#
#                                            description        subject spatial  \
# 2    <p>ครั้งหนึ่งนานมาแล้วในฤดูฝน มีการเตรียมปักดำ...  นิทานพื้นบ้าน     ไทย
# 32   <p>กาลครั้งหนึ่งนานมาแล้ว ในฤดูฝนนั้นจะมาการเต...  นิทานพื้นบ้าน     ไทย
# ...

# %% [markdown]
# ### การวนลูป record ในตาราง  (```.iterrows```)

# %%
folk_df.head()
# Out:
#                 title            type             creator  \
# 0        ตาบอดคลำช้าง  นิทานประจำถิ่น    อ่อนตา ประกาเวสา
# 1      ขอคำกระฮอกด่อน    ตำนานปรัมปรา           พ่อใหญ่นู
# 2  ก่องข้าวน้อยฆ่าแม่      นิทานชีวิต  หนูเวียง แก้วเวียง
# 3           บักหำน้อย          มุขตลก     สมหวัง ปานพายัพ
# 4          รื้อบ่อน้ำ          มุขตลก      บุญศรี เกสเสโร
#
#                                          description        subject spatial  \
# 0  <p>&nbsp; &nbsp; &nbsp; &nbsp; มีคนตาบอดหกคน ซ...  นิทานพื้นบ้าน     ไทย
# 1  <p>&nbsp; &nbsp; &nbsp; ในขณะนั้นมีพญาผู้หนึ่ง...  นิทานพื้นบ้าน     ไทย
# 2  <p>ครั้งหนึ่งนานมาแล้วในฤดูฝน มีการเตรียมปักดำ...  นิทานพื้นบ้าน     ไทย
# 3  <p>เรื่องมีอยู่ว่า ณ โรงเรียนแห่งหนึ่งของภาคอี...  นิทานพื้นบ้าน     ไทย
# 4  <p>วันหนึ่งพ่อตากับลูกเขยพากันไปรื้อบ่อน้ำใช้ ...  นิทานพื้นบ้าน     ไทย
#
#    temporal language rights                         license  \
# 0       NaN      ไทย    NaN  สัญญาอนุญาตของครีเอทีฟคอมมอนส์
# ...

# %%
this_data = folk_df[['title','type','creator']].dropna()

# %%
this_data.groupby('type').count()
# Out:
#                  title  creator
# type
# ตำนานปรัมปรา         8        8
# นิทานชีวิต          22       22
# นิทานประจำถิ่น      15       15
# นิทานผี              2        2
# นิทานมหัศจรรย์      12       12
# นิทานศาสนา           3        3
# นิทานสัตว์           5        5
# นิทานอธิบายเหตุ     25       25
# มุขตลก              33       33

# %%
for each_row in this_data.iterrows():
    print(each_row,end='\n*************************\n')
# Out:
# (0, title          ตาบอดคลำช้าง
# type         นิทานประจำถิ่น
# creator    อ่อนตา ประกาเวสา
# Name: 0, dtype: object)
# *************************
# (1, title      ขอคำกระฮอกด่อน
# type         ตำนานปรัมปรา
# creator         พ่อใหญ่นู
# Name: 1, dtype: object)
# *************************
# (2, title      ก่องข้าวน้อยฆ่าแม่
# type               นิทานชีวิต
# creator    หนูเวียง แก้วเวียง
# Name: 2, dtype: object)
# *************************
# (3, title            บักหำน้อย
# type                มุขตลก
# creator    สมหวัง ปานพายัพ
# Name: 3, dtype: object)
# *************************
# (4, title          รื้อบ่อน้ำ
# type               มุขตลก
# creator    บุญศรี เกสเสโร
# Name: 4, dtype: object)
# *************************
# (5, title      กว่าจะได้เป็นเจ้านายก็ติดการอุจจาระปัสสาวะ
# type                                           มุขตลก
# creator                            พัชราภรณ์ เข็มเพชร
# Name: 5, dtype: object)
# *************************
# (6, title        ตำนานกุดนางใย
# ...

# %% [markdown]
# # Quiz 9
#
# - วนลูปนับว่ามีนิทานที่มีคำว่า แม่ หรือ พ่อ ในชื่อเรื่อง ทั้งหมดกี่เรื่อง เรื่องอะไรบ้าง
#
# - มีคำดังกล่าวใน นิทานชีวิต หรือ นิทานประจำถิ่นมากกว่ากัน
#
# - คนแต่งคนไหน ชอบแต่งนิทานที่มีชื่อเรื่อง ว่า แม่ หรือ พ่อ มากที่สุด

# %%
# prompt: จาก data this_data วนลูปนับว่ามีนิทานที่มีคำว่า แม่ หรือ พ่อ ในชื่อเรื่อง ทั้งหมดกี่เรื่อง เรื่องอะไรบ้าง

count = 0
stories = []
for index, row in this_data.iterrows():
  if 'แม่' in row['title'] or 'พ่อ' in row['title']:
    count += 1
    stories.append(row['title'])

print(f"There are {count} stories with 'แม่' or 'พ่อ' in the title.")
print("The stories are:")
for story in stories:
  print(story)
# Out:
# There are 19 stories with 'แม่' or 'พ่อ' in the title.
# The stories are:
# ก่องข้าวน้อยฆ่าแม่
# หลวงพ่อน้องงัว
# หลวงพ่อกับเณรน้อย
# แม่ใหญ่แฮก
# ปัญญาของพ่อ
# แม่เฒ่ากับลูกเขย
# หลวงพ่อกลัวผีหลอก
# หลวงพ่อเข้าลอดช่อง
# ลูกหลงพ่อ
# ก่องข้าวน้อยฆ่าแม่
# คนจีนกับหลวงพ่อเจ้าอาวาส
# หลวงพ่อกินขี้ไก่โป่
# หลวงพ่อม้าน้อยหลังแอ่น
# พ่อเฒ่ากับลูกเขยกินข้าวนำกัน
# พ่อใหญ่หัวล้าน
# หลวงพ่อกะทอเกลือ
# แม่หม้ายตาโป
# ด้ามมีดพ่อท่าน
# พระคุณแม่โพสพ

# %%
# prompt: มีคำดังกล่าวใน นิทานชีวิต หรือ นิทานประจำถิ่นมากกว่ากัน บอกจำนวนด้วย

import pandas
import pandas as pd
import os
from google.colab import drive
from bs4 import BeautifulSoup

# ... (preceding code)

count_life = 0
count_local = 0
for index, row in this_data.iterrows():
  if ('แม่' in row['title'] or 'พ่อ' in row['title']) and row['type'] == 'นิทานชีวิต':
    count_life += 1
  elif ('แม่' in row['title'] or 'พ่อ' in row['title']) and row['type'] == 'นิทานประจำถิ่น':
    count_local += 1

if count_life > count_local:
  print(f"There are more stories with 'แม่' or 'พ่อ' in the title in นิทานชีวิต ({count_life} stories) than in นิทานประจำถิ่น ({count_local} stories).")
elif count_local > count_life:
  print(f"There are more stories with 'แม่' or 'พ่อ' in the title in นิทานประจำถิ่น ({count_local} stories) than in นิทานชีวิต ({count_life} stories).")
else:
  print(f"There are an equal number of stories with 'แม่' or 'พ่อ' in the title in both นิทานชีวิต and นิทานประจำถิ่น ({count_life} stories each).")
# Out:
# There are an equal number of stories with 'แม่' or 'พ่อ' in the title in both นิทานชีวิต and นิทานประจำถิ่น (2 stories each).

# %%
# prompt: คนแต่งคนไหน ชอบแต่งนิทานที่มีชื่อเรื่อง ว่า แม่ หรือ พ่อ มากที่สุด (พร้อมทั้งอธิบาย code แต่ละบรรทัดด้วย)

# สร้าง dictionary เพื่อเก็บจำนวนนิทานที่มีคำว่า 'แม่' หรือ 'พ่อ' ในชื่อเรื่องสำหรับแต่ละคนแต่ง
creator_counts = {}
for index, row in this_data.iterrows():
  if 'แม่' in row['title'] or 'พ่อ' in row['title']:
    creator = row['creator']
    if creator not in creator_counts:
      creator_counts[creator] = 0
    creator_counts[creator] += 1

# หาคนแต่งที่มีจำนวนนิทานมากที่สุด
max_count = 0
most_prolific_creator = None
for creator, count in creator_counts.items():
  if count > max_count:
    max_count = count
    most_prolific_creator = creator

print(f"The creator who wrote the most stories with 'แม่' or 'พ่อ' in the title is {most_prolific_creator} with {max_count} stories.")
# Out:
# The creator who most frequently writes stories with 'แม่' or 'พ่อ' in the title is: หนูเวียง แก้วเวียง
# They have written 2 such stories.

# %%
creator_counts
# Out:
# {'หนูเวียง แก้วเวียง': 2,
#  'สุบิน คำยางจ้อง': 1,
#  'ปรางค์ทิพย์ บุญสีลา': 1,
#  'ชลิตา โพธิสาร': 1,
#  'ไพบูลย์ ระหา': 1,
#  'สุนีย์ คุณโพธิ์': 1,
#  'เสาร์ จันกอ': 2,
#  'จันทร์ โพธิ์ไทสง': 1,
#  'อ่อนตา ประกาเวสา': 2,
#  'สมศรี ถอนภูเขียว': 1,
#  'พรม วรรณศิริ': 1,
#  'สุรพันธ์ บุญชู': 1,
#  'เลิศ ประนัดเด': 1,
#  'อาคม  ปาสานัย': 1,
#  'ลาภ  เพ็ญสวัสดิ์': 1,
#  'นวลจันทร์  จีนเมือง': 1}

# %% [markdown]
# ### การวนลูป แบบมองตารางแพนด้าส์(pandas dataframe) เป็น numpy array  (```.iloc```)

# %% [markdown]
# #Quiz9
# - print ชื่อนิทานทั้งหมดที่มีคำว่า ปู่ ออกมา

# %%
# prompt: print ชื่อนิทานทั้งหมดที่มีคำว่า ปู่ ออกมา ใช้ iloc

# ... (preceding code)

for i in range(this_data.shape[0]):
  if 'ปู่' in this_data.iloc[i,0]:
    print(this_data.iloc[i,0])
# Out:
# เขาปู่เขาย่า

# %% [markdown]
# # Dataset ใหม่ ที่มี ตัวเลข

# %%
movie_df = pd.read_csv('/content/drive/MyDrive/data_viz_2024_DATA/IMDb Movies India.csv', encoding='latin-1')
print(movie_df.shape)
movie_df.head()
# Out:
# (15509, 10)
#                                  Name    Year Duration            Genre  \
# 0                                         NaN      NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                         #Homecoming  (2021)   90 min   Drama, Musical
# 3                             #Yaaram  (2019)  110 min  Comedy, Romance
# 4                   ...And Once Again  (2010)  105 min            Drama
#
#    Rating Votes            Director       Actor 1             Actor 2  \
# 0     NaN   NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN   NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35          Ovais Khan       Prateik          Ishita Raj
# 4     NaN   NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# ...

# %%
# prompt: ถ้า dropna ข้อมูลเหลือกี่ %

remaining_percentage = (movie_df.dropna().shape[0] / movie_df.shape[0]) * 100
print(f"Remaining data after dropna: {remaining_percentage:.2f}%")
# Out:
# Remaining data after dropna: 36.49%

# %%
movie_df = movie_df.dropna()

# %%
# prompt: ตัด ( ) ออกจากค่าใน column Year และแปลงค่าเป็นตัวเลข

# ตัด ( ) ออกจากค่าใน column Year และแปลงค่าเป็นตัวเลข
movie_df['Year'] = movie_df['Year'].str.replace('(', '').str.replace(')', '').astype(int)

# %%
movie_df.head()
# Out:
#                                  Name  Year Duration  \
# 1  #Gadhvi (He thought he was Gandhi)  2019  109 min
# 3                             #Yaaram  2019  110 min
# 5                ...Aur Pyaar Ho Gaya  1997  147 min
# 6                           ...Yahaan  2005  142 min
# 8                  ?: A Question Mark  2012   82 min
#
#                        Genre  Rating  Votes        Director          Actor 1  \
# 1                      Drama     7.0      8   Gaurav Bakshi     Rasika Dugal
# 3            Comedy, Romance     4.4     35      Ovais Khan          Prateik
# 5     Comedy, Drama, Musical     4.7    827    Rahul Rawail       Bobby Deol
# 6        Drama, Romance, War     7.4  1,086  Shoojit Sircar  Jimmy Sheirgill
# 8  Horror, Mystery, Thriller     5.6    326   Allyson Patel        Yash Dave
#
#                   Actor 2          Actor 3
# 1          Vivek Ghamande    Arvind Jangid
# 3              Ishita Raj  Siddhant Kapoor
# 5  Aishwarya Rai Bachchan    Shammi Kapoor
# ...

# %%
movie_df['Duration'] = movie_df['Duration'].str.replace(' min', '').astype(int)

# %%
movie_df
# Out:
#                                      Name  Year  Duration  \
# 1      #Gadhvi (He thought he was Gandhi)  2019       109
# 3                                 #Yaaram  2019       110
# 5                    ...Aur Pyaar Ho Gaya  1997       147
# 6                               ...Yahaan  2005       142
# 8                      ?: A Question Mark  2012        82
# ...                                   ...   ...       ...
# 15493                              Zubaan  2015       115
# 15494                            Zubeidaa  2001       153
# 15503                     Zulm Ki Zanjeer  1989       125
# 15505                               Zulmi  1999       129
# 15508                        Zulm-O-Sitam  1998       130
#
#                            Genre  Rating  Votes         Director  \
# 1                          Drama     7.0      8    Gaurav Bakshi
# 3                Comedy, Romance     4.4     35       Ovais Khan
# 5         Comedy, Drama, Musical     4.7    827     Rahul Rawail
# ...

# %% [markdown]
# # Function ตัวช่วยใน pandas

# %% [markdown]
# ### ```.describe()``` คำนวณค่าทางสถิติของข้อมูลที่เป็นตัวเลข

# %%
movie_df.describe()
# Out:
#               Year     Duration       Rating
# count  5659.000000  5659.000000  5659.000000
# mean   1996.247570   133.439124     5.898533
# std      19.741839    25.319939     1.381165
# min    1931.000000    21.000000     1.100000
# 25%    1983.000000   119.000000     5.000000
# 50%    2002.000000   135.000000     6.100000
# 75%    2013.000000   150.000000     6.900000
# max    2021.000000   321.000000    10.000000

# %%
# prompt: สร้างตารางของ​ Director ที่มี Name เยอะที่สุด เอาแค่ข้อมูลของคนที่เยอะที่สุด

# นับจำนวนหนังที่แต่ละ Director กำกับ
director_counts = movie_df['Director'].value_counts()

# หา Director ที่กำกับหนังเยอะที่สุด
most_prolific_director = director_counts.index[0]
num_movies = director_counts[0]

# สร้างตารางของ Director ที่กำกับหนังเยอะที่สุด
most_prolific_director_df = movie_df[movie_df['Director'] == most_prolific_director]

# แสดงตาราง
print(f"Director with most movies: {most_prolific_director} ({num_movies} movies)")
most_prolific_director_df
# Out:
# Director with most movies: David Dhawan (41 movies)
#                                     Name  Year  Duration  \
# 239                          Aag Ka Gola  1990       180
# 397                            Aandhiyan  1990       145
# 408                              Aankhen  1993       170
# 1008                               Andaz  1994       167
# 1596              Bade Miyan Chote Miyan  1998       140
# 1794                       Banarasi Babu  1997       126
# 2408                          Biwi No. 1  1999       159
# 2478                       Bol Radha Bol  1992       164
# 2754                      Chal Mere Bhai  2000       136
# 2903                     Chashme Baddoor  2013       121
# 3098                  Chor Machaaye Shor  2002       145
# 3230                        Coolie No. 1  1995       143
# 3232                        Coolie No. 1  2020       134
# 3562                     Deewana Mastana  1997       140
# ...

# %% [markdown]
# ### ```.mean()``` คำนวณค่าเฉลี่ยของข้อมูลโดยไม่สนใจ missing

# %%
movie_df[movie_df['Director'] == most_prolific_director]['Rating'].mean()
# Out:
# 5.226829268292683

# %%
movie_df[movie_df['Director'] == most_prolific_director].describe()
# Out:
#               Year    Duration     Rating
# count    41.000000   41.000000  41.000000
# mean   1999.804878  145.170732   5.226829
# std       7.460628   15.006503   1.060430
# min    1989.000000  121.000000   2.900000
# 25%    1995.000000  134.000000   4.600000
# 50%    1998.000000  143.000000   5.100000
# 75%    2002.000000  160.000000   6.100000
# max    2020.000000  180.000000   6.700000

# %% [markdown]
# # HW6
# บรรยายเกี่ยวกับผู้กำกับชั้นนำของอินเดีย 3 คน ว่าทำไมเราถึงคิดว่าเป็นผู้กำกับชั้นนำ และชั้นนำยังไง
#
# (พรีเซ็นคนละ 3 นาที slides)

# %% [markdown]
# ### ```.isnull()```

# %%
data_covid.isnull()
# Out:
#          No.  announce_date  ...  district_of_onset   risk
# 0      False          False  ...               True  False
# 1      False          False  ...               True  False
# 2      False          False  ...              False  False
# 3      False          False  ...               True  False
# 4      False          False  ...               True  False
# ...      ...            ...  ...                ...    ...
# 12648  False          False  ...              False  False
# 12649  False          False  ...              False  False
# 12650  False          False  ...              False  False
# 12651  False          False  ...              False  False
# 12652  False          False  ...              False  False
#
# [12653 rows x 10 columns]

# %% [markdown]
# # next
# *   .describe
# *   .mean
# *   HW วนลูป missing .isnull
# *   ต่อตารางแกน X แกน y
# *   .groupby
# *   save table

# %%
controlled_drugs = stopandsearch_df['Object of search'][5]
article_for_theft = stopandsearch_df['Object of search'][382]

# %% [markdown]
# # Task
# Write Python code to determine whether there were more stop and search incidents involving white English/Welsh/Scottish/Northern Irish individuals in 'city of london' or 'cambrigeshire' during February 2025, and by how many, using the data from the file "2025-02" in Google Drive.

# %% [markdown]
# ## Load february 2025 data
#
# ### Subtask:
# Load the stop and search data for February 2025 from the appropriate file in Google Drive.

# %% [markdown]
# **Reasoning**:
# I need to construct the file path for the February 2025 data and load it into a pandas DataFrame. I will assume the file is located in the same directory as the January file. Then I will display the head and shape of the dataframe to verify the loading.

# %%
february_path = '/content/drive/MyDrive/Python&DataViz2025/Data/2025-02/2025-02-bedfordshire-stop-and-search.csv'
february_df = pd.read_csv(february_path)
display(february_df.head())
display(february_df.shape)
# Out:
#             Type                       Date  Part of a policing operation  \
# 0  Person search  2025-02-01T04:26:00+00:00                         False
# 1  Person search  2025-02-01T16:00:00+00:00                         False
# 2  Person search  2025-02-01T16:00:00+00:00                         False
# 3  Person search  2025-02-01T18:00:00+00:00                         False
# 4  Person search  2025-02-01T19:00:00+00:00                          True
#
#    Policing operation   Latitude  Longitude Gender Age range  \
# 0                 NaN  52.086887  -0.262838   Male     10-17
# 1                 NaN  51.889120  -0.520461   Male     18-24
# 2                 NaN  51.889120  -0.520461   Male     18-24
# 3                 NaN        NaN        NaN   Male   over 34
# 4                 NaN  51.883065  -0.407199   Male     25-34
#
#                               Self-defined ethnicity  \
# 0  White - English/Welsh/Scottish/Northern Irish/...
# ...

# %% [markdown]
# ## Filter for ethnicity
#
# ### Subtask:
# Filter the DataFrame to include only records where the 'Self-defined ethnicity' is 'White - English/Welsh/Scottish/Northern Irish/...'.

# %% [markdown]
# **Reasoning**:
# I will create a boolean mask to filter the `february_df` for rows where the 'Self-defined ethnicity' is 'White - English/Welsh/Scottish/Northern Irish/...'. Then I will apply this mask to create a new DataFrame `white_ethnicity_df` and display its first 5 rows to confirm the result.

# %%
white_ethnicity_df = february_df[february_df['Self-defined ethnicity'] == 'White - English/Welsh/Scottish/Northern Irish/...']
display(white_ethnicity_df.head())
# Out:
# Empty DataFrame
# Columns: [Type, Date, Part of a policing operation, Policing operation, Latitude, Longitude, Gender, Age range, Self-defined ethnicity, Officer-defined ethnicity, Legislation, Object of search, Outcome, Outcome linked to object of search, Removal of more than just outer clothing]
# Index: []

# %% [markdown]
# **Reasoning**:
# The previous filtering resulted in an empty DataFrame. This indicates that the exact string 'White - English/Welsh/Scottish/Northern Irish/...' is not present in the 'Self-defined ethnicity' column of `february_df`. I need to inspect the unique values in this column to find the correct string for white ethnicity or identify if there is no data for this ethnicity in the loaded dataset.

# %%
display(february_df['Self-defined ethnicity'].unique())
# Out:
# array(['White - English/Welsh/Scottish/Northern Irish/British',
#        'Black/African/Caribbean/Black British - African',
#        'White - Any other White background',
#        'Other ethnic group - Not stated',
#        'Asian/Asian British - Any other Asian background', nan,
#        'Asian/Asian British - Pakistani',
#        'Black/African/Caribbean/Black British - Any other Black/African/Caribbean background',
#        'Black/African/Caribbean/Black British - Caribbean',
#        'White - Irish', 'Asian/Asian British - Bangladeshi',
#        'Mixed/Multiple ethnic groups - Any other Mixed/Multiple ethnic background',
#        'Other ethnic group - Any other ethnic group',
#        'Mixed/Multiple ethnic groups - White and Black Caribbean',
#        'Asian/Asian British - Indian',
#        'Mixed/Multiple ethnic groups - White and Asian',
#        'White - Gypsy or Irish Traveller'], dtype=object)

# %% [markdown]
# **Reasoning**:
# Based on the unique values, the correct string for white ethnicity is 'White - English/Welsh/Scottish/Northern Irish/British'. I will use this correct string to filter the `february_df` to create the `white_ethnicity_df` and then display the first 5 rows to confirm.

# %%
white_ethnicity_df = february_df[february_df['Self-defined ethnicity'] == 'White - English/Welsh/Scottish/Northern Irish/British']
display(white_ethnicity_df.head())
# Out:
#                         Type                       Date  \
# 0              Person search  2025-02-01T04:26:00+00:00
# 1              Person search  2025-02-01T16:00:00+00:00
# 2              Person search  2025-02-01T16:00:00+00:00
# 4              Person search  2025-02-01T19:00:00+00:00
# 5  Person and Vehicle search  2025-02-01T23:40:00+00:00
#
#    Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                         False                 NaN  52.086887  -0.262838
# 1                         False                 NaN  51.889120  -0.520461
# 2                         False                 NaN  51.889120  -0.520461
# 4                          True                 NaN  51.883065  -0.407199
# 5                         False                 NaN  51.907813  -0.552236
#
#   Gender Age range                             Self-defined ethnicity  \
# 0   Male     10-17  White - English/Welsh/Scottish/Northern Irish/...
# ...

# %% [markdown]
# ## Filter for locations
#
# ### Subtask:
# Further filter the data to include only records from 'city of london' or 'cambrigeshire'.

# %% [markdown]
# **Reasoning**:
# Examine the available columns to identify location information and then filter the DataFrame based on the desired locations ('city of london' or 'cambrigeshire'). Since there is no explicit city column, I will check if the data is confined to a specific region based on the available data and the task context (Bedfordshire police force data loaded in the previous step). If the data is only for Bedfordshire, I will finish the task with failure as I cannot filter for 'city of london' or 'cambrigeshire'.

# %%
display(white_ethnicity_df.columns)
display(white_ethnicity_df['Latitude'].describe())
display(white_ethnicity_df['Longitude'].describe())
# Out:
# Index(['Type', 'Date', 'Part of a policing operation', 'Policing operation',
#        'Latitude', 'Longitude', 'Gender', 'Age range',
#        'Self-defined ethnicity', 'Officer-defined ethnicity', 'Legislation',
#        'Object of search', 'Outcome', 'Outcome linked to object of search',
#        'Removal of more than just outer clothing'],
#       dtype='object')
# count    75.000000
# mean     51.989778
# std       0.142868
# min      51.871289
# 25%      51.879796
# 50%      51.907813
# 75%      52.131362
# max      52.631301
# Name: Latitude, dtype: float64
# count    75.000000
# mean     -0.462957
# std       0.083263
# min      -0.664630
# 25%      -0.481027
# 50%      -0.464127
# 75%      -0.420283
# max      -0.258347
# Name: Longitude, dtype: float64

# %% [markdown]
# ## Filter for locations
#
# ### Subtask:
# Further filter the data to include only records from 'city of london' or 'cambrigeshire'.

# %% [markdown]
# ## Filter for locations
#
# ### Subtask:
# Further filter the data to include only records from 'city of london' or 'cambrigeshire'.

# %% [markdown]
# **Reasoning**:
# Construct the file paths for the February 2025 stop and search data for 'city of london' and 'cambridgeshire', load the data into separate dataframes, and display the head and shape of each to verify the loading and inspect the data.

# %%
cityoflondon_feb_path = '/content/drive/MyDrive/Python&DataViz2025/Data/2025-02/2025-02-city-of-london-stop-and-search.csv'
cambridgeshire_feb_path = '/content/drive/MyDrive/Python&DataViz2025/Data/2025-02/2025-02-cambridgeshire-stop-and-search.csv'

cityoflondon_feb_df = pd.read_csv(cityoflondon_feb_path)
cambridgeshire_feb_df = pd.read_csv(cambridgeshire_feb_path)

print("City of London data:")
display(cityoflondon_feb_df.head())
display(cityoflondon_feb_df.shape)

print("\nCambridgeshire data:")
display(cambridgeshire_feb_df.head())
display(cambridgeshire_feb_df.shape)
# Out:
# City of London data:
#                         Type                       Date  \
# 0              Person search  2025-02-01T04:35:33+00:00
# 1              Person search  2025-02-01T14:24:45+00:00
# 2              Person search  2025-02-01T21:28:25+00:00
# 3              Person search  2025-02-01T21:35:37+00:00
# 4  Person and Vehicle search  2025-02-02T01:02:10+00:00
#
#    Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                           NaN                 NaN        NaN        NaN
# 1                           NaN                 NaN  51.514267  -0.079838
# 2                           NaN                 NaN  51.511406  -0.075866
# 3                           NaN                 NaN  51.511965  -0.075453
# 4                           NaN                 NaN  51.509797  -0.083600
#
#   Gender Age range                             Self-defined ethnicity  \
# 0   Male     25-34  White - English/Welsh/Scottish/Northern Irish/...
# ...

# %% [markdown]
# **Reasoning**:
# Filter both dataframes to include only records where the 'Self-defined ethnicity' is 'White - English/Welsh/Scottish/Northern Irish/British' and display the shape of the filtered dataframes.

# %%
cityoflondon_white_feb_df = cityoflondon_feb_df[cityoflondon_feb_df['Self-defined ethnicity'] == 'White - English/Welsh/Scottish/Northern Irish/British']
cambridgeshire_white_feb_df = cambridgeshire_feb_df[cambridgeshire_feb_df['Self-defined ethnicity'] == 'White - English/Welsh/Scottish/Northern Irish/British']

print("Shape of filtered City of London data:")
display(cityoflondon_white_feb_df.shape)

print("\nShape of filtered Cambridgeshire data:")
display(cambridgeshire_white_feb_df.shape)
# Out:
# Shape of filtered City of London data:
# (15, 15)
# Shape of filtered Cambridgeshire data:
# (69, 15)

# %% [markdown]
# **Reasoning**:
# Calculate the number of stop and search incidents for the specified ethnicity in each location and determine which location had more incidents and by how many. Then, report the finish status and the dataframes used.

# %%
cityoflondon_count = cityoflondon_white_feb_df.shape[0]
cambridgeshire_count = cambridgeshire_white_feb_df.shape[0]

print(f"Number of incidents in City of London: {cityoflondon_count}")
print(f"Number of incidents in Cambridgeshire: {cambridgeshire_count}")

if cityoflondon_count > cambridgeshire_count:
    difference = cityoflondon_count - cambridgeshire_count
    print(f"City of London had more incidents by {difference}.")
elif cambridgeshire_count > cityoflondon_count:
    difference = cambridgeshire_count - cityoflondon_count
    print(f"Cambridgeshire had more incidents by {difference}.")
else:
    print("Both locations had the same number of incidents.")
# Out:
# Number of incidents in City of London: 15
# Number of incidents in Cambridgeshire: 69
# Cambridgeshire had more incidents by 54.

# %% [markdown]
# ## Compare counts
#
# ### Subtask:
# Count the number of incidents for 'city of london' and 'cambrigeshire' within the filtered data and compare the counts.

# %% [markdown]
# **Reasoning**:
# Get the number of rows for each filtered dataframe and compare them to determine which location had more incidents and by how many.

# %%
cityoflondon_count = cityoflondon_white_feb_df.shape[0]
cambridgeshire_count = cambridgeshire_white_feb_df.shape[0]

print(f"Number of incidents in City of London: {cityoflondon_count}")
print(f"Number of incidents in Cambridgeshire: {cambridgeshire_count}")

if cityoflondon_count > cambridgeshire_count:
    difference = cityoflondon_count - cambridgeshire_count
    print(f"City of London had more incidents by {difference}.")
elif cambridgeshire_count > cityoflondon_count:
    difference = cambridgeshire_count - cityoflondon_count
    print(f"Cambridgeshire had more incidents by {difference}.")
else:
    print("Both locations had the same number of incidents.")
# Out:
# Number of incidents in City of London: 15
# Number of incidents in Cambridgeshire: 69
# Cambridgeshire had more incidents by 54.

# %% [markdown]
# ## Summary:
#
# ### Q&A
# There were more stop and search incidents involving white English/Welsh/Scottish/Northern Irish individuals in 'cambridgeshire' than in 'city of london' during February 2025.
#
# ### Data Analysis Key Findings
# *   In February 2025, there were 15 stop and search incidents involving white English/Welsh/Scottish/Northern Irish individuals in the 'city of london'.
# *   In February 2025, there were 69 stop and search incidents involving white English/Welsh/Scottish/Northern Irish individuals in 'cambridgeshire'.
# *   'Cambridgeshire' had 54 more incidents than 'city of london' (69 vs 15).
#
# ### Insights or Next Steps
# *   Further analysis could investigate the reasons for the significant difference in the number of stop and search incidents for this demographic between the two locations.
# *   Compare these figures with other ethnicities and other months to understand broader trends.

# %% [markdown]
# **Reasoning**:
# Filter both dataframes to include only records where the 'Self-defined ethnicity' is 'White - English/Welsh/Scottish/Northern Irish/British' and display the shape of the filtered dataframes.

# %% [markdown]
# **Reasoning**:
# Calculate the number of stop and search incidents for the specified ethnicity in each location and determine which location had more incidents and by how many. Then, report the finish status and the dataframes used.

# %% [markdown]
# # Task
# Analyze the stop and search data for Bedfordshire, City of London, and Cambridgeshire from January to May 2025 to determine which city has the lowest and highest total number of stop and searches for individuals of Asian ethnicity across the five months. Use the following data files: "2025-01-bedfordshire-street.csv", "2025-01-city-of-london-street.csv", "2025-01-cambridgeshire-street.csv", "2025-02-bedfordshire-street.csv", "2025-02-city-of-london-street.csv", "2025-02-cambridgeshire-street.csv", "2025-03-bedfordshire-street.csv", "2025-03-city-of-london-street.csv", "2025-03-cambridgeshire-street.csv", "2025-04-bedfordshire-street.csv", "2025-04-city-of-london-street.csv", "2025-04-cambridgeshire-street.csv", "2025-05-bedfordshire-street.csv", "2025-05-city-of-london-street.csv", "2025-05-cambridgeshire-street.csv".

# %% [markdown]
# ## Load data for all five months
#
# ### Subtask:
# Load the stop and search data for each of the five months (January to May 2025) into separate dataframes.

# %% [markdown]
# **Reasoning**:
# Construct the file paths for all the required CSV files, initialize an empty dictionary, and then iterate through the file paths to load each CSV into a pandas DataFrame and store it in the dictionary with a descriptive key. Finally, display the dictionary keys.

# %%
file_paths = [
    '/content/drive/MyDrive/Python&DataViz2025/Data/2025-01/2025-01-bedfordshire-street.csv',
    '/content/drive/MyDrive/Python&DataViz2025/Data/2025-01/2025-01-city-of-london-street.csv',
    '/content/drive/MyDrive/Python&DataViz2025/Data/2025-01/2025-01-cambridgeshire-street.csv',
    '/content/drive/MyDrive/Python&DataViz2025/Data/2025-02/2025-02-bedfordshire-street.csv',
    '/content/drive/MyDrive/Python&DataViz2025/Data/2025-02/2025-02-city-of-london-street.csv',
    '/content/drive/MyDrive/Python&DataViz2025/Data/2025-02/2025-02-cambridgeshire-street.csv',
    '/content/drive/MyDrive/Python&DataViz2025/Data/2025-03/2025-03-bedfordshire-street.csv',
    '/content/drive/MyDrive/Python&DataViz2025/Data/2025-03/2025-03-city-of-london-street.csv',
    '/content/drive/MyDrive/Python&DataViz2025/Data/2025-03/2025-03-cambridgeshire-street.csv',
    '/content/drive/MyDrive/Python&DataViz2025/Data/2025-04/2025-04-bedfordshire-street.csv',
    '/content/drive/MyDrive/Python&DataViz2025/Data/2025-04/2025-04-city-of-london-street.csv',
    '/content/drive/MyDrive/Python&DataViz2025/Data/2025-04/2025-04-cambridgeshire-street.csv',
    '/content/drive/MyDrive/Python&DataViz2025/Data/2025-05/2025-05-bedfordshire-street.csv',
    '/content/drive/MyDrive/Python&DataViz2025/Data/2025-05/2025-05-city-of-london-street.csv',
    '/content/drive/MyDrive/Python&DataViz2025/Data/2025-05/2025-05-cambridgeshire-street.csv'
]

dataframes = {}

for file_path in file_paths:
    # Extract information from the file path to create a key
    parts = file_path.split('/')
    month_year = parts[-2]  # e.g., '2025-01'
    location_name = parts[-1].split('-')[2] # e.g., 'bedfordshire'
    key = f"{location_name}_{month_year.replace('-', '_')}_df"

    try:
        df = pd.read_csv(file_path)
        dataframes[key] = df
    except FileNotFoundError:
        print(f"File not found: {file_path}")

print("Loaded dataframes:")
print(dataframes.keys())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3779493569.py in <cell line: 0>()
#      27
#      28     try:
# ---> 29         df = pd.read_csv(file_path)
#      30         dataframes[key] = df
#      31     except FileNotFoundError:
#
# NameError: name 'pd' is not defined

# %% [markdown]
# **Reasoning**:
# The previous code failed because the pandas library was not imported with the alias 'pd'. I will import pandas as pd and then re-execute the code to load the dataframes.

# %%
import pandas as pd

file_paths = [
    '/content/drive/MyDrive/Python&DataViz2025/Data/2025-01/2025-01-bedfordshire-street.csv',
    '/content/drive/MyDrive/Python&DataViz2025/Data/2025-01/2025-01-city-of-london-street.csv',
    '/content/drive/MyDrive/Python&DataViz2025/Data/2025-01/2025-01-cambridgeshire-street.csv',
    '/content/drive/MyDrive/Python&DataViz2025/Data/2025-02/2025-02-bedfordshire-street.csv',
    '/content/drive/MyDrive/Python&DataViz2025/Data/2025-02/2025-02-city-of-london-street.csv',
    '/content/drive/MyDrive/Python&DataViz2025/Data/2025-02/2025-02-cambridgeshire-street.csv',
    '/content/drive/MyDrive/Python&DataViz2025/Data/2025-03/2025-03-bedfordshire-street.csv',
    '/content/drive/MyDrive/Python&DataViz2025/Data/2025-03/2025-03-city-of-london-street.csv',
    '/content/drive/MyDrive/Python&DataViz2025/Data/2025-03/2025-03-cambridgeshire-street.csv',
    '/content/drive/MyDrive/Python&DataViz2025/Data/2025-04/2025-04-bedfordshire-street.csv',
    '/content/drive/MyDrive/Python&DataViz2025/Data/2025-04/2025-04-city-of-london-street.csv',
    '/content/drive/MyDrive/Python&DataViz2025/Data/2025-04/2025-04-cambridgeshire-street.csv',
    '/content/drive/MyDrive/Python&DataViz2025/Data/2025-05/2025-05-bedfordshire-street.csv',
    '/content/drive/MyDrive/Python&DataViz2025/Data/2025-05/2025-05-city-of-london-street.csv',
    '/content/drive/MyDrive/Python&DataViz2025/Data/2025-05/2025-05-cambridgeshire-street.csv'
]

dataframes = {}

for file_path in file_paths:
    # Extract information from the file path to create a key
    parts = file_path.split('/')
    month_year = parts[-2]  # e.g., '2025-01'
    location_name = parts[-1].split('-')[2] # e.g., 'bedfordshire'
    key = f"{location_name}_{month_year.replace('-', '_')}_df"

    try:
        df = pd.read_csv(file_path)
        dataframes[key] = df
    except FileNotFoundError:
        print(f"File not found: {file_path}")

print("Loaded dataframes:")
print(dataframes.keys())
# Out:
# File not found: /content/drive/MyDrive/Python&DataViz2025/Data/2025-03/2025-03-bedfordshire-street.csv
# File not found: /content/drive/MyDrive/Python&DataViz2025/Data/2025-03/2025-03-cambridgeshire-street.csv
# File not found: /content/drive/MyDrive/Python&DataViz2025/Data/2025-04/2025-04-bedfordshire-street.csv
# File not found: /content/drive/MyDrive/Python&DataViz2025/Data/2025-04/2025-04-cambridgeshire-street.csv
# File not found: /content/drive/MyDrive/Python&DataViz2025/Data/2025-05/2025-05-bedfordshire-street.csv
# File not found: /content/drive/MyDrive/Python&DataViz2025/Data/2025-05/2025-05-cambridgeshire-street.csv
# Loaded dataframes:
# dict_keys(['bedfordshire_2025_01_df', 'city_2025_01_df', 'cambridgeshire_2025_01_df', 'bedfordshire_2025_02_df', 'city_2025_02_df', 'cambridgeshire_2025_02_df', 'city_2025_03_df', 'city_2025_04_df', 'city_2025_05_df'])

# %% [markdown]
# ## Filter for asian ethnicity
#
# ### Subtask:
# For each monthly dataframe and for each location (Bedfordshire, City of London, Cambridgeshire), filter the data to include only records where the 'Self-defined ethnicity' indicates an Asian background.

# %% [markdown]
# **Reasoning**:
# Define the list of Asian ethnicity strings and then iterate through the dataframes dictionary to filter each dataframe by this list, storing the results in a new dictionary. Finally, display the keys of the new dictionary to confirm the filtering.

# %%
asian_ethnicities = [
    'Asian/Asian British - Any other Asian background',
    'Asian/Asian British - Pakistani',
    'Asian/Asian British - Bangladeshi',
    'Asian/Asian British - Indian'
]

asian_dataframes = {}

for key, df in dataframes.items():
    if 'Self-defined ethnicity' in df.columns:
        filtered_df = df[df['Self-defined ethnicity'].isin(asian_ethnicities)]
        asian_dataframes[f"asian_{key}"] = filtered_df
    else:
        print(f"DataFrame {key} does not have 'Self-defined ethnicity' column.")

print("Filtered dataframes for Asian ethnicity:")
print(asian_dataframes.keys())
# Out:
# DataFrame bedfordshire_2025_01_df does not have 'Self-defined ethnicity' column.
# DataFrame city_2025_01_df does not have 'Self-defined ethnicity' column.
# DataFrame cambridgeshire_2025_01_df does not have 'Self-defined ethnicity' column.
# DataFrame bedfordshire_2025_02_df does not have 'Self-defined ethnicity' column.
# DataFrame city_2025_02_df does not have 'Self-defined ethnicity' column.
# DataFrame cambridgeshire_2025_02_df does not have 'Self-defined ethnicity' column.
# DataFrame city_2025_03_df does not have 'Self-defined ethnicity' column.
# DataFrame city_2025_04_df does not have 'Self-defined ethnicity' column.
# DataFrame city_2025_05_df does not have 'Self-defined ethnicity' column.
# Filtered dataframes for Asian ethnicity:
# dict_keys([])

# %% [markdown]
# ## Filter for asian ethnicity
#
# ### Subtask:
# Retry filtering the data for Asian ethnicity by first identifying the correct column containing ethnicity information.

# %% [markdown]
# **Reasoning**:
# Iterate through each dataframe to find the ethnicity column.

# %%
asian_ethnicities = [
    'Asian/Asian British - Any other Asian background',
    'Asian/Asian British - Pakistani',
    'Asian/Asian British - Bangladeshi',
    'Asian/Asian British - Indian'
]

asian_dataframes = {}

for key, df in dataframes.items():
    print(f"Columns in {key}: {df.columns.tolist()}")
    ethnicity_column = None
    # Check for possible ethnicity column names
    for col in df.columns:
        if 'ethnicity' in col.lower():
            ethnicity_column = col
            break

    if ethnicity_column:
        print(f"Found ethnicity column: {ethnicity_column} in {key}")
        filtered_df = df[df[ethnicity_column].isin(asian_ethnicities)]
        asian_dataframes[f"asian_{key}"] = filtered_df
    else:
        print(f"No suitable ethnicity column found in {key}.")

print("Filtered dataframes for Asian ethnicity:")
print(asian_dataframes.keys())
# Out:
# Columns in bedfordshire_2025_01_df: ['Crime ID', 'Month', 'Reported by', 'Falls within', 'Longitude', 'Latitude', 'Location', 'LSOA code', 'LSOA name', 'Crime type', 'Last outcome category', 'Context']
# No suitable ethnicity column found in bedfordshire_2025_01_df.
# Columns in city_2025_01_df: ['Crime ID', 'Month', 'Reported by', 'Falls within', 'Longitude', 'Latitude', 'Location', 'LSOA code', 'LSOA name', 'Crime type', 'Last outcome category', 'Context']
# No suitable ethnicity column found in city_2025_01_df.
# Columns in cambridgeshire_2025_01_df: ['Crime ID', 'Month', 'Reported by', 'Falls within', 'Longitude', 'Latitude', 'Location', 'LSOA code', 'LSOA name', 'Crime type', 'Last outcome category', 'Context']
# No suitable ethnicity column found in cambridgeshire_2025_01_df.
# Columns in bedfordshire_2025_02_df: ['Crime ID', 'Month', 'Reported by', 'Falls within', 'Longitude', 'Latitude', 'Location', 'LSOA code', 'LSOA name', 'Crime type', 'Last outcome category', 'Context']
# ...

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The initial attempt to load the data failed due to the pandas library not being imported.
# *   Upon importing pandas, several `FileNotFoundError` messages were encountered, indicating that not all expected data files were available.
# *   Despite the file errors, some dataframes were successfully loaded for Bedfordshire (January, February), City of London (January to May), and Cambridgeshire (January, February).
# *   During the filtering stage for Asian ethnicity, it was discovered that none of the loaded dataframes contained a column named 'Self-defined ethnicity'.
# *   A subsequent attempt to find an ethnicity column by searching for columns containing "ethnicity" in their name also failed, as no such column was present in any of the loaded dataframes.
# *   Due to the absence of an ethnicity column, the analysis of stop and searches for individuals of Asian ethnicity could not be performed as requested by the task.
#
# ### Insights or Next Steps
#
# *   The current data is not suitable for analyzing stop and searches by ethnicity due to the missing ethnicity column.
# *   Obtain data that includes a column detailing the self-defined ethnicity of the individuals stopped and searched to proceed with the analysis.

# %%
from google.colab import drive
import pandas as pd
import os

# Mount Google Drive
drive.mount('/content/drive')

# เส้นทางหลักของโฟลเดอร์ข้อมูล
base_path = '/content/drive/MyDrive/Python&DataViz2025/Data/'

# Generate list of file paths for stop-and-search data across all months and locations
file_paths = []
for month in os.listdir(base_path):
    month_path = os.path.join(base_path, month)
    if os.path.isdir(month_path):
        for file in os.listdir(month_path):
            if 'stop-and-search' in file and file.endswith('.csv'):
                file_paths.append(os.path.join(month_path, file))

# Load and concatenate all dataframes, adding a 'City' column
all_data = []
for filepath in file_paths:
    try:
        df = pd.read_csv(filepath)
        city = filepath.split('/')[-1].replace('-stop-and-search.csv', '').split('-', 2)[-1].strip()
        df['City'] = city
        all_data.append(df)
    except Exception as e:
        print(f"อ่านไฟล์ไม่ได้: {filepath} : {e}")

combined_df = pd.concat(all_data, ignore_index=True)

# Filter for Asian ethnicity and count by city in one step
asian_counts = combined_df[combined_df['Self-defined ethnicity'].str.contains('Asian', na=False)]['City'].value_counts().to_dict()

# Display results
if asian_counts:
    most_city = max(asian_counts, key=asian_counts.get)
    fewest_city = min(asian_counts, key=asian_counts.get)
    print(f"เมืองที่มีจำนวนผู้ถูกเรียกค้นที่เป็นคน Asia น้อยที่สุด คือเมือง {fewest_city} จำนวน {asian_counts[fewest_city]} คน")
    print(f"เมืองที่มีจำนวนผู้ถูกเรียกค้นที่เป็นคน Asia มากที่สุด คือเมือง {most_city} จำนวน {asian_counts[most_city]} คน")
else:
    print("ไม่พบข้อมูลที่เกี่ยวข้องกับผู้มีเชื้อสายเอเชีย")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# เมืองที่มีจำนวนผู้ถูกเรียกค้นที่เป็นคน Asia น้อยที่สุด คือเมือง durham จำนวน 5 คน
# เมืองที่มีจำนวนผู้ถูกเรียกค้นที่เป็นคน Asia มากที่สุด คือเมือง west-midlands จำนวน 2104 คน

# %% [markdown]
# ## สำรวจวิธีการอ่านและรวมไฟล์ข้อมูล
#
# ### Subtask:
# สำรวจวิธีการอื่นๆ ในการอ่านไฟล์ CSV หลายไฟล์จากโฟลเดอร์ย่อยๆ และรวมเป็น DataFrame เดียว นอกเหนือจากการวนลูปและ `pd.concat` แบบตรงไปตรงมา

# %% [markdown]
# **Reasoning**:
# The subtask requires exploring alternative ways to read and combine multiple CSV files. I will use the `glob` library to find the file paths, a list comprehension to read the files, and then explore alternative pandas functions for concatenation. I will then add the 'City' column and display the head and shape of the resulting DataFrame.

# %%
missing_age_rows = stopandsearch_df[stopandsearch_df['Age range'].isnull()]
display(missing_age_rows)
# Out:
#               Type                       Date  Part of a policing operation  \
# 52   Person search  2025-01-06T08:00:00+00:00                         False
# 77   Person search  2025-01-07T15:10:00+00:00                          True
# 83   Person search  2025-01-07T22:31:00+00:00                         False
# 228  Person search  2025-01-19T18:45:00+00:00                         False
# 231  Person search  2025-01-19T18:45:00+00:00                         False
# 242  Person search  2025-01-20T15:55:00+00:00                         False
# 243  Person search  2025-01-20T15:55:00+00:00                         False
# 244  Person search  2025-01-20T15:55:00+00:00                         False
# 245  Person search  2025-01-20T15:55:00+00:00                         False
# 282  Person search  2025-01-25T15:40:00+00:00                         False
# 296  Person search  2025-01-26T18:40:00+00:00                         False
# ...
